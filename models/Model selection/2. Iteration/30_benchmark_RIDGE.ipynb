# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer
from sklearn.linear_model import Ridge

# %%
# Set parameters for linear regression

# ridge parameters for random search
fit_intercept = [True, False]
copy_X = [True, False]
alpha = [0.1, 0.5, 1, 2, 5, 10, 20, 50, 100]
tol = [0.0001, 0.001, 0.01, 0.1, 1, 10, 100]
solver = ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']

# Create the random grid
random_grid = {'fit_intercept': fit_intercept,
                'copy_X': copy_X,
                'alpha': alpha,
                'tol': tol,
                'solver': solver}

# %%
#Define MASE Metric
def mean_absolute_scaled_error(y_true, y_pred):
    mase=0
    # Define numerator as the forecast error
    numerator = (np.abs(y_true - y_pred))

    # Define denominator as the mean absolute error of the in-sample one-step naive forecast
    y_true_ohne_1 = y_true[1:].reset_index(drop=True)
    y_true_ohne_ende = y_true[:-1].reset_index(drop=True)
    denominator = np.mean(np.abs(y_true_ohne_1 - y_true_ohne_ende))

    mase = np.mean(np.abs(numerator / denominator))

    return mase

scorer_mase= make_scorer(mean_absolute_scaled_error, greater_is_better=False)

# %%
# Load the data
data = pd.read_parquet('/Users/paddy/Documents/GitHub/Masterthesis_ML/data/03_30min_dataset.parquet')

# Convert the date column to datetime
data['date'] = pd.to_datetime(data['date']) #,format='%d/%m/%y %H:%M:%S').dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
#Feature engineering
# Create a new column for the time
data['time'] = [x for x in range(0, len(data))]

# Drop nan values
data = data.dropna()

# Rename column count to y
data = data.rename(columns={'count': 'y'})

# %%
# Set y to the last column
cols = list(data.columns.values) #Make a list of all of the columns in the df
cols.pop(cols.index('y')) #Remove y from list
data = data[cols+['y']] #Create new dataframe with columns in the order you want

# Define the feature columns and the target column
feature_cols = ['time']
target_col = 'y'

# drop the date column
train_data = np.delete(data, 0, 1) 

# Split the data into X and y
X_train, y_train = train_data[:, :-1], train_data[:, -1]

# %%
#vgl: https://lightrun.com/answers/scikit-learn-scikit-learn-grid_search-feeding-parameters-to-scorer-functions

# X and y to pandas dataframe
X_train = pd.DataFrame(X_train)
y_train = pd.Series(y_train)

# %%
# Set Cross Validation to 5 iterations
tscv = TimeSeriesSplit(n_splits=5)

# %%
# Instantiate model
model = Ridge()

search = RandomizedSearchCV(estimator = model, 
                               param_distributions = random_grid, 
                               n_iter = 25, 
                               cv = tscv,
                               refit=True, 
                               verbose=3, 
                               random_state=42, 
                               n_jobs = -1, 
                               scoring=scorer_mase, #make_scorer(scorer_mase, greater_is_better=True), #'neg_root_mean_squared_error', #
                               error_score=np.nan)

# %%
# Fit the random search model
search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=0.001;, score=-1.472 total time=   0.0s
# [CV 4/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=0.001;, score=-1.442 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=cholesky, tol=0.01;, score=-1.472 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=cholesky, tol=0.01;, score=-1.442 total time=   0.0s
# [CV 3/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=0.001;, score=-1.472 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=cholesky, tol=0.01;, score=-1.472 total time=   0.0s
# [CV 1/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=0.1;, score=-2.739 total time=   0.0s
# [CV 2/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=0.1;, score=-2.433 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=cholesky, tol=0.01;, score=-1.362 total time=   0.0s
# [CV 3/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=0.1;, score=-2.033 total time=   0.0s
# [CV 4/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=0.1;, score=-1.862 total time=   0.0s
# [CV 5/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=0.1;, score=-1.631 total time=   0.0s
# [CV 1/5] END alpha=50, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.462 total time=   0.0s
# [CV 2/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=0.001;, score=-1.561 total time=   0.0s
# [CV 3/5] END alpha=50, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.504 total time=   0.0s
# [CV 2/5] END alpha=50, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.648 total time=   0.0s
# [CV 4/5] END alpha=50, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.519 total time=   0.0s
# [CV 5/5] END alpha=50, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.458 total time=   0.0s
# [CV 1/5] END alpha=20, copy_X=False, fit_intercept=True, solver=lsqr, tol=0.001;, score=-1.472 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=cholesky, tol=0.01;, score=-1.561 total time=   0.0s
# [CV 2/5] END alpha=20, copy_X=False, fit_intercept=True, solver=lsqr, tol=0.001;, score=-1.561 total time=   0.0s
# [CV 3/5] END alpha=20, copy_X=False, fit_intercept=True, solver=lsqr, tol=0.001;, score=-1.472 total time=   0.0s
# [CV 4/5] END alpha=20, copy_X=False, fit_intercept=True, solver=lsqr, tol=0.001;, score=-1.442 total time=   0.0s
# [CV 1/5] END alpha=2, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.01;, score=-2.739 total time=   0.0s
# [CV 5/5] END alpha=20, copy_X=False, fit_intercept=True, solver=lsqr, tol=0.001;, score=-1.362 total time=   0.0s
# [CV 2/5] END alpha=2, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.01;, score=-2.433 total time=   0.0s
# [CV 3/5] END alpha=2, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.01;, score=-2.033 total time=   0.0s
# [CV 4/5] END alpha=2, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.01;, score=-1.862 total time=   0.0s
# [CV 5/5] END alpha=2, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.01;, score=-1.631 total time=   0.0s
# [CV 1/5] END alpha=100, copy_X=False, fit_intercept=True, solver=sag, tol=0.0001;, score=-1.472 total time=   0.0s
# [CV 5/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=0.001;, score=-1.362 total time=   0.0s
# [CV 2/5] END alpha=100, copy_X=False, fit_intercept=True, solver=sag, tol=0.0001;, score=-1.561 total time=   0.0s
# [CV 3/5] END alpha=100, copy_X=False, fit_intercept=True, solver=sag, tol=0.0001;, score=-1.472 total time=   0.0s
# [CV 1/5] END alpha=1, copy_X=False, fit_intercept=True, solver=sag, tol=1;, score=-2.044 total time=   0.0s
# [CV 4/5] END alpha=100, copy_X=False, fit_intercept=True, solver=sag, tol=0.0001;, score=-1.442 total time=   0.0s
# [CV 2/5] END alpha=1, copy_X=False, fit_intercept=True, solver=sag, tol=1;, score=-2.077 total time=   0.0s
# [CV 3/5] END alpha=1, copy_X=False, fit_intercept=True, solver=sag, tol=1;, score=-11.729 total time=   0.0s
# [CV 4/5] END alpha=1, copy_X=False, fit_intercept=True, solver=sag, tol=1;, score=-2.068 total time=   0.0s
# [CV 5/5] END alpha=1, copy_X=False, fit_intercept=True, solver=sag, tol=1;, score=-1.967 total time=   0.0s
# [CV 1/5] END alpha=10, copy_X=False, fit_intercept=False, solver=saga, tol=10;, score=-2.741 total time=   0.0s
# [CV 2/5] END alpha=10, copy_X=False, fit_intercept=False, solver=saga, tol=10;, score=-2.364 total time=   0.0s
# [CV 3/5] END alpha=10, copy_X=False, fit_intercept=False, solver=saga, tol=10;, score=-2.236 total time=   0.0s
# [CV 4/5] END alpha=10, copy_X=False, fit_intercept=False, solver=saga, tol=10;, score=-1.964 total time=   0.0s
# [CV 5/5] END alpha=10, copy_X=False, fit_intercept=False, solver=saga, tol=10;, score=-2.313 total time=   0.0s
# [CV 1/5] END alpha=1, copy_X=True, fit_intercept=False, solver=svd, tol=0.01;, score=-2.739 total time=   0.0s
# [CV 5/5] END alpha=100, copy_X=False, fit_intercept=True, solver=sag, tol=0.0001;, score=-1.362 total time=   0.0s
# [CV 2/5] END alpha=1, copy_X=True, fit_intercept=False, solver=svd, tol=0.01;, score=-2.433 total time=   0.0s
# [CV 3/5] END alpha=1, copy_X=True, fit_intercept=False, solver=svd, tol=0.01;, score=-2.033 total time=   0.0s
# [CV 4/5] END alpha=1, copy_X=True, fit_intercept=False, solver=svd, tol=0.01;, score=-1.862 total time=   0.0s
# [CV 1/5] END alpha=100, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=1;, score=-2.041 total time=   0.0s
# [CV 3/5] END alpha=100, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=1;, score=-2.024 total time=   0.0s
# [CV 5/5] END alpha=1, copy_X=True, fit_intercept=False, solver=svd, tol=0.01;, score=-1.631 total time=   0.0s
# [CV 5/5] END alpha=100, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=1;, score=-1.891 total time=   0.0s
# [CV 2/5] END alpha=100, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=1;, score=-2.126 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.461 total time=   0.0s
# [CV 4/5] END alpha=100, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=1;, score=-1.967 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.803 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.555 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.436 total time=   0.0s
# [CV 1/5] END alpha=5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.001;, score=-1.472 total time=   0.0s
# [CV 2/5] END alpha=5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.001;, score=-1.561 total time=   0.0s
# [CV 3/5] END alpha=5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.001;, score=-1.472 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.362 total time=   0.0s
# [CV 4/5] END alpha=5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.001;, score=-1.442 total time=   0.0s
# [CV 5/5] END alpha=5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.001;, score=-1.362 total time=   0.0s
# [CV 2/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sag, tol=10;, score=-2.182 total time=   0.0s
# [CV 1/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sag, tol=10;, score=-1.499 total time=   0.0s
# [CV 3/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sag, tol=10;, score=-2.516 total time=   0.0s
# [CV 4/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sag, tol=10;, score=-5.605 total time=   0.0s
# [CV 1/5] END alpha=20, copy_X=True, fit_intercept=False, solver=saga, tol=10;, score=-2.121 total time=   0.0s
# [CV 2/5] END alpha=20, copy_X=True, fit_intercept=False, solver=saga, tol=10;, score=-2.701 total time=   0.0s
# [CV 3/5] END alpha=20, copy_X=True, fit_intercept=False, solver=saga, tol=10;, score=-1.621 total time=   0.0s
# [CV 5/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sag, tol=10;, score=-1.518 total time=   0.0s
# [CV 4/5] END alpha=20, copy_X=True, fit_intercept=False, solver=saga, tol=10;, score=-1.548 total time=   0.0s
# [CV 5/5] END alpha=20, copy_X=True, fit_intercept=False, solver=saga, tol=10;, score=-1.404 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=saga, tol=0.001;, score=-1.561 total time=   0.0s
# [CV 1/5] END alpha=1, copy_X=False, fit_intercept=False, solver=lsqr, tol=0.001;, score=-2.739 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=saga, tol=0.001;, score=-1.472 total time=   0.0s
# [CV 2/5] END alpha=1, copy_X=False, fit_intercept=False, solver=lsqr, tol=0.001;, score=-2.433 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=saga, tol=0.001;, score=-1.442 total time=   0.0s
# [CV 3/5] END alpha=1, copy_X=False, fit_intercept=False, solver=lsqr, tol=0.001;, score=-2.033 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=saga, tol=0.001;, score=-1.472 total time=   0.0s
# [CV 5/5] END alpha=1, copy_X=False, fit_intercept=False, solver=lsqr, tol=0.001;, score=-1.631 total time=   0.0s
# [CV 4/5] END alpha=1, copy_X=False, fit_intercept=False, solver=lsqr, tol=0.001;, score=-1.862 total time=   0.0s
# [CV 1/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=1;, score=-2.739 total time=   0.0s
# [CV 4/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=1;, score=-1.862 total time=   0.0s
# [CV 2/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=1;, score=-2.433 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=True, fit_intercept=False, solver=auto, tol=100;, score=-2.033 total time=   0.0s
# [CV 5/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=1;, score=-1.631 total time=   0.0s
# [CV 3/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=1;, score=-2.033 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=True, fit_intercept=False, solver=auto, tol=100;, score=-1.862 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=saga, tol=0.001;, score=-1.362 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=True, fit_intercept=False, solver=auto, tol=100;, score=-2.739 total time=   0.0s
# [CV 2/5] END alpha=0.1, copy_X=True, fit_intercept=False, solver=cholesky, tol=0.01;, score=-2.433 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=True, fit_intercept=False, solver=auto, tol=100;, score=-1.631 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=True, fit_intercept=False, solver=auto, tol=100;, score=-2.433 total time=   0.0s
# [CV 1/5] END alpha=20, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.001;, score=-2.739 total time=   0.0s
# [CV 3/5] END alpha=0.1, copy_X=True, fit_intercept=False, solver=cholesky, tol=0.01;, score=-2.033 total time=   0.0s
# [CV 1/5] END alpha=0.1, copy_X=True, fit_intercept=False, solver=cholesky, tol=0.01;, score=-2.739 total time=   0.0s
# [CV 2/5] END alpha=20, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.001;, score=-2.433 total time=   0.0s
# [CV 4/5] END alpha=0.1, copy_X=True, fit_intercept=False, solver=cholesky, tol=0.01;, score=-1.862 total time=   0.0s
# [CV 3/5] END alpha=20, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.001;, score=-2.033 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.1;, score=-1.442 total time=   0.0s
# [CV 5/5] END alpha=0.1, copy_X=True, fit_intercept=False, solver=cholesky, tol=0.01;, score=-1.631 total time=   0.0s
# [CV 5/5] END alpha=20, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.001;, score=-1.631 total time=   0.0s
# [CV 3/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=0.0001;, score=-2.033 total time=   0.0s
# [CV 4/5] END alpha=20, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.001;, score=-1.862 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.1;, score=-1.362 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.1;, score=-1.472 total time=   0.0s
# [CV 1/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=0.0001;, score=-2.739 total time=   0.0s
# [CV 4/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=0.0001;, score=-1.862 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.1;, score=-1.561 total time=   0.0s
# [CV 5/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=0.0001;, score=-1.631 total time=   0.0s
# [CV 2/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=0.0001;, score=-2.433 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.1;, score=-1.472 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=svd, tol=0.0001;, score=-1.472 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=svd, tol=0.0001;, score=-1.561 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=svd, tol=0.0001;, score=-1.472 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=svd, tol=0.0001;, score=-1.442 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=svd, tol=0.0001;, score=-1.362 total time=   0.0s
# [CV 1/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=100;, score=-1.463 total time=   0.0s
# [CV 2/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=100;, score=-1.554 total time=   0.0s
# [CV 3/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=100;, score=-1.476 total time=   0.0s
# [CV 4/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=100;, score=-1.445 total time=   0.0s
# [CV 5/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=100;, score=-1.362 total time=   0.0s
# RandomizedSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#                    estimator=Ridge(), n_iter=25, n_jobs=-1,
#                    param_distributions={'alpha': [0.1, 0.5, 1, 2, 5, 10, 20, 50,
#                                                   100],
#                                         'copy_X': [True, False],
#                                         'fit_intercept': [True, False],
#                                         'solver': ['auto', 'svd', 'cholesky',
#                                                    'lsqr', 'sparse_cg', 'sag',
#                                                    'saga'],
#                                         'tol': [0.0001, 0.001, 0.01, 0.1, 1, 10,
#                                                 100]},
#                    random_state=42,
#                    scoring=make_scorer(mean_absolute_scaled_error, greater_is_better=False),
#                    verbose=3)

# %%
print('Best Score: %s' % search.best_score_)
print('Best Hyperparameters: %s' % search.best_params_)
print('Best Model: %s' % search.best_estimator_)
print('Best Index: %s' % search.best_index_)
print('CV Results: %s' % search.cv_results_)
print('Refit Time: %s' % search.refit_time_)
print('Scorer: %s' % search.scorer_)
# Out:
# Best Score: -1.4599924911606017
# Best Hyperparameters: {'tol': 100, 'solver': 'sparse_cg', 'fit_intercept': True, 'copy_X': False, 'alpha': 10}
# Best Model: Ridge(alpha=10, copy_X=False, solver='sparse_cg', tol=100)
# Best Index: 24
# CV Results: {'mean_fit_time': array([0.0029933 , 0.00409799, 0.0024498 , 0.00385413, 0.00322838,
#        0.00207348, 0.01462126, 0.00229897, 0.00233574, 0.0018671 ,
#        0.00225959, 0.00198584, 0.00181785, 0.00222297, 0.00195942,
#        0.00678921, 0.00171604, 0.0015698 , 0.00165   , 0.00158639,
#        0.00171967, 0.00178638, 0.00180783, 0.0018692 , 0.00177507]), 'std_fit_time': array([0.00105301, 0.00354459, 0.0005649 , 0.00184304, 0.00139602,
#        0.00033161, 0.01039407, 0.00058768, 0.00037833, 0.00030916,
#        0.00055746, 0.00041791, 0.00038419, 0.00059138, 0.00050423,
#        0.00334477, 0.00036835, 0.00034466, 0.00021566, 0.00034527,
#        0.00033136, 0.000321  , 0.00034682, 0.00038414, 0.00019905]), 'mean_score_time': array([0.00163875, 0.00284142, 0.00166435, 0.00480065, 0.00164356,
#        0.0019331 , 0.00177317, 0.00158381, 0.00156441, 0.00145845,
#        0.00177956, 0.00145817, 0.00178337, 0.00143867, 0.00156941,
#        0.00153747, 0.00140538, 0.00143065, 0.00160742, 0.00137753,
#        0.00214357, 0.00142064, 0.00144253, 0.00165181, 0.00137033]), 'std_score_time': array([1.42716860e-04, 1.44369020e-03, 4.09451269e-05, 4.26016612e-03,
#        1.04835509e-04, 8.25618830e-04, 1.55906166e-04, 1.01764244e-04,
#        1.23279015e-04, 3.99785802e-05, 3.59669105e-04, 8.84122188e-05,
#        5.77181766e-04, 4.74009234e-05, 3.75409464e-04, 8.53340829e-05,
#        6.46112766e-05, 1.90834472e-04, 4.75506715e-04, 3.40884878e-05,
#        1.44166388e-03, 7.27006392e-05, 7.18317789e-05, 2.27083973e-04,
#        6.25681582e-05]), 'param_tol': masked_array(data=[0.001, 0.01, 0.1, 100, 0.001, 0.01, 0.0001, 1, 10,
#                    0.01, 1, 100, 0.001, 10, 10, 0.001, 0.001, 1, 100,
#                    0.01, 0.001, 0.1, 0.0001, 0.0001, 100],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_solver': masked_array(data=['sparse_cg', 'cholesky', 'svd', 'saga', 'lsqr',
#                    'sparse_cg', 'sag', 'sag', 'saga', 'svd', 'sparse_cg',
#                    'saga', 'lsqr', 'sag', 'saga', 'saga', 'lsqr', 'svd',
#                    'auto', 'cholesky', 'sparse_cg', 'lsqr', 'sparse_cg',
#                    'svd', 'sparse_cg'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_fit_intercept': masked_array(data=[True, True, False, True, True, False, True, True,
#                    False, False, False, True, True, False, False, True,
#                    False, False, False, False, False, True, False, True,
#                    True],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_copy_X': masked_array(data=[False, True, False, False, False, False, False, False,
#                    False, True, True, False, True, True, True, True,
#                    False, False, True, True, False, True, True, True,
#                    False],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_alpha': masked_array(data=[10, 0.5, 100, 50, 20, 2, 100, 1, 10, 1, 100, 0.5, 5, 5,
#                    20, 0.5, 1, 100, 0.5, 0.1, 20, 0.5, 5, 0.5, 10],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'params': [{'tol': 0.001, 'solver': 'sparse_cg', 'fit_intercept': True, 'copy_X': False, 'alpha': 10}, {'tol': 0.01, 'solver': 'cholesky', 'fit_intercept': True, 'copy_X': True, 'alpha': 0.5}, {'tol': 0.1, 'solver': 'svd', 'fit_intercept': False, 'copy_X': False, 'alpha': 100}, {'tol': 100, 'solver': 'saga', 'fit_intercept': True, 'copy_X': False, 'alpha': 50}, {'tol': 0.001, 'solver': 'lsqr', 'fit_intercept': True, 'copy_X': False, 'alpha': 20}, {'tol': 0.01, 'solver': 'sparse_cg', 'fit_intercept': False, 'copy_X': False, 'alpha': 2}, {'tol': 0.0001, 'solver': 'sag', 'fit_intercept': True, 'copy_X': False, 'alpha': 100}, {'tol': 1, 'solver': 'sag', 'fit_intercept': True, 'copy_X': False, 'alpha': 1}, {'tol': 10, 'solver': 'saga', 'fit_intercept': False, 'copy_X': False, 'alpha': 10}, {'tol': 0.01, 'solver': 'svd', 'fit_intercept': False, 'copy_X': True, 'alpha': 1}, {'tol': 1, 'solver': 'sparse_cg', 'fit_intercept': False, 'copy_X': True, 'alpha': 100}, {'tol': 100, 'solver': 'saga', 'fit_intercept': True, 'copy_X': False, 'alpha': 0.5}, {'tol': 0.001, 'solver': 'lsqr', 'fit_intercept': True, 'copy_X': True, 'alpha': 5}, {'tol': 10, 'solver': 'sag', 'fit_intercept': False, 'copy_X': True, 'alpha': 5}, {'tol': 10, 'solver': 'saga', 'fit_intercept': False, 'copy_X': True, 'alpha': 20}, {'tol': 0.001, 'solver': 'saga', 'fit_intercept': True, 'copy_X': True, 'alpha': 0.5}, {'tol': 0.001, 'solver': 'lsqr', 'fit_intercept': False, 'copy_X': False, 'alpha': 1}, {'tol': 1, 'solver': 'svd', 'fit_intercept': False, 'copy_X': False, 'alpha': 100}, {'tol': 100, 'solver': 'auto', 'fit_intercept': False, 'copy_X': True, 'alpha': 0.5}, {'tol': 0.01, 'solver': 'cholesky', 'fit_intercept': False, 'copy_X': True, 'alpha': 0.1}, {'tol': 0.001, 'solver': 'sparse_cg', 'fit_intercept': False, 'copy_X': False, 'alpha': 20}, {'tol': 0.1, 'solver': 'lsqr', 'fit_intercept': True, 'copy_X': True, 'alpha': 0.5}, {'tol': 0.0001, 'solver': 'sparse_cg', 'fit_intercept': False, 'copy_X': True, 'alpha': 5}, {'tol': 0.0001, 'solver': 'svd', 'fit_intercept': True, 'copy_X': True, 'alpha': 0.5}, {'tol': 100, 'solver': 'sparse_cg', 'fit_intercept': True, 'copy_X': False, 'alpha': 10}], 'split0_test_score': array([-1.4720588 , -1.4720588 , -2.73942085, -1.46208749, -1.4720588 ,
#        -2.73942089, -1.4720985 , -2.04445935, -2.74054845, -2.73942089,
#        -2.04123346, -1.46051037, -1.4720588 , -1.49885828, -2.12140539,
#        -1.472039  , -2.73942089, -2.73942085, -2.73942089, -2.73942089,
#        -2.73942088, -1.4720588 , -2.73942089, -1.4720588 , -1.46295719]), 'split1_test_score': array([-1.56080324, -1.56080324, -2.43253525, -1.64799374, -1.56080324,
#        -2.43253525, -1.56080451, -2.07706249, -2.36370627, -2.43253525,
#        -2.12644257, -1.80289188, -1.56080324, -2.18248471, -2.70061451,
#        -1.56088142, -2.43253525, -2.43253525, -2.43253525, -2.43253525,
#        -2.43253525, -1.56080324, -2.43253525, -1.56080324, -1.55406772]), 'split2_test_score': array([ -1.47217461,  -1.47217461,  -2.03317658,  -1.50372521,
#         -1.47217461,  -2.03317658,  -1.47217507, -11.72943799,
#         -2.23606632,  -2.03317658,  -2.02426068,  -1.55469852,
#         -1.47217461,  -2.51633709,  -1.62076689,  -1.47217872,
#         -2.03317658,  -2.03317658,  -2.03317658,  -2.03317658,
#         -2.03317658,  -1.47217461,  -2.03317658,  -1.47217461,
#         -1.47627204]), 'split3_test_score': array([-1.44208028, -1.44208028, -1.86203282, -1.51901465, -1.44208028,
#        -1.86203282, -1.44208061, -2.06849919, -1.96408624, -1.86203282,
#        -1.96673743, -1.43629325, -1.44208028, -5.6048027 , -1.54780146,
#        -1.44208125, -1.86203282, -1.86203282, -1.86203282, -1.86203282,
#        -1.86203282, -1.44208028, -1.86203282, -1.44208028, -1.44460822]), 'split4_test_score': array([-1.36196994, -1.36196994, -1.63126409, -1.45793261, -1.36196994,
#        -1.63126409, -1.36196989, -1.96743623, -2.31264507, -1.63126409,
#        -1.89105389, -1.36242211, -1.36196994, -1.5179369 , -1.40357478,
#        -1.36196979, -1.63126409, -1.63126409, -1.63126409, -1.63126409,
#        -1.63126409, -1.36196994, -1.63126409, -1.36196994, -1.36205729]), 'mean_test_score': array([-1.46181737, -1.46181737, -2.13968592, -1.51815074, -1.46181737,
#        -2.13968593, -1.46182572, -3.97737905, -2.32341047, -2.13968593,
#        -2.00994561, -1.52336323, -1.46181737, -2.66408394, -1.87883261,
#        -1.46183003, -2.13968593, -2.13968592, -2.13968593, -2.13968593,
#        -2.13968592, -1.46181737, -2.13968593, -1.46181737, -1.45999249]), 'std_test_score': array([0.06382699, 0.06382699, 0.39808817, 0.06904688, 0.06382699,
#        0.39808818, 0.06382867, 3.87622218, 0.24999466, 0.39808818,
#        0.0784316 , 0.15267736, 0.06382699, 1.5213808 , 0.47670045,
#        0.06385073, 0.39808818, 0.39808817, 0.39808818, 0.39808818,
#        0.39808818, 0.06382699, 0.39808818, 0.06382699, 0.06156613]), 'rank_test_score': array([ 3,  5, 14, 10,  2, 18,  8, 25, 23, 19, 13, 11,  4, 24, 12,  9, 20,
#        14, 21, 22, 16,  5, 17,  5,  1], dtype=int32)}
# Refit Time: 0.002210855484008789
# Scorer: make_scorer(mean_absolute_scaled_error, greater_is_better=False)
