# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer
from sklearn.linear_model import Ridge

# %%
# Set parameters for linear regression

# ridge parameters for random search
fit_intercept = [True, False]
copy_X = [True, False]
alpha = [0.1, 0.5, 1, 2, 5, 10, 20, 50, 100]
tol = [0.0001, 0.001, 0.01, 0.1, 1, 10, 100]
solver = ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']

# Create the random grid
random_grid = {'fit_intercept': fit_intercept,
                'copy_X': copy_X,
                'alpha': alpha,
                'tol': tol,
                'solver': solver}

# %%
#Define MASE Metric
def mean_absolute_scaled_error(y_true, y_pred):
    mase=0
    # Define numerator as the forecast error
    numerator = (np.abs(y_true - y_pred))

    # Define denominator as the mean absolute error of the in-sample one-step naive forecast
    y_true_ohne_1 = y_true[1:].reset_index(drop=True)
    y_true_ohne_ende = y_true[:-1].reset_index(drop=True)
    denominator = np.mean(np.abs(y_true_ohne_1 - y_true_ohne_ende))

    mase = np.mean(np.abs(numerator / denominator))

    return mase

scorer_mase= make_scorer(mean_absolute_scaled_error, greater_is_better=False)

# %%
# Load the data
data = pd.read_parquet('/Users/paddy/Documents/GitHub/Masterthesis_ML/data/03_032022_032023_taxi_rides.parquet')

# Convert the date column to datetime
data['date'] = pd.to_datetime(data['date']) #,format='%d/%m/%y %H:%M:%S').dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
#Feature engineering
# Create a new column for the time
data['time'] = [x for x in range(0, len(data))]

# Create the lagged features
lags = 24 + 1

# Create the lagged features
for i in range(1, lags):
    data['lag' + str(i)] = data['count'].shift(i)

# Drop the first three rows
data = data.dropna().reset_index(drop=True)

# Define the feature columns and the target column
feature_cols = [ f'lag{i}' for i in range(1, lags)]
target_col = 'y'

# Drop nan values
data = data.dropna()

# Rename column count to y
data = data.rename(columns={'count': 'y'})

# %%
# Set y to the last column
cols = list(data.columns.values) #Make a list of all of the columns in the df
cols.pop(cols.index('y')) #Remove y from list
data = data[cols+['y']] #Create new dataframe with columns in the order you want

# drop the date column
train_data = np.delete(data, 0, 1) 

# Split the data into X and y
X_train, y_train = train_data[:, :-1], train_data[:, -1]

# %%
#vgl: https://lightrun.com/answers/scikit-learn-scikit-learn-grid_search-feeding-parameters-to-scorer-functions

# X and y to pandas dataframe
X_train = pd.DataFrame(X_train)
y_train = pd.Series(y_train)

# %%
# Set Cross Validation to 5 iterations
tscv = TimeSeriesSplit(n_splits=5)

# %%
# Instantiate model
model = Ridge()

search = RandomizedSearchCV(estimator = model, 
                               param_distributions = random_grid, 
                               n_iter = 25, 
                               cv = tscv,
                               refit=True, 
                               verbose=3, 
                               random_state=42, 
                               n_jobs = -1, 
                               scoring=scorer_mase, #make_scorer(scorer_mase, greater_is_better=True), #'neg_root_mean_squared_error', #
                               error_score=np.nan)

# %%
# Fit the random search model
search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 3/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=cholesky, tol=0.01;, score=-0.703 total time=   0.0s
# [CV 5/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=0.001;, score=-0.661 total time=   0.0s
# [CV 2/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=0.001;, score=-0.790 total time=   0.0s
# [CV 3/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=0.001;, score=-0.703 total time=   0.0s
# [CV 4/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=0.001;, score=-0.667 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=cholesky, tol=0.01;, score=-0.790 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=cholesky, tol=0.01;, score=-0.683 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=cholesky, tol=0.01;, score=-0.667 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=cholesky, tol=0.01;, score=-0.661 total time=   0.0s
# [CV 1/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=0.1;, score=-0.690 total time=   0.0s
# [CV 2/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=0.1;, score=-0.790 total time=   0.0s
# [CV 3/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=0.1;, score=-0.707 total time=   0.0s
# [CV 4/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=0.1;, score=-0.671 total time=   0.0s
# [CV 5/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=0.1;, score=-0.666 total time=   0.0s
# [CV 1/5] END alpha=50, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-0.840 total time=   0.0s
# [CV 1/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=0.001;, score=-0.683 total time=   0.0s
# [CV 2/5] END alpha=50, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.553 total time=   0.0s
# [CV 3/5] END alpha=50, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-0.959 total time=   0.0s
# [CV 4/5] END alpha=50, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-0.994 total time=   0.0s
# [CV 5/5] END alpha=50, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.072 total time=   0.0s
# [CV 1/5] END alpha=20, copy_X=False, fit_intercept=True, solver=lsqr, tol=0.001;, score=-0.684 total time=   0.0s
# [CV 2/5] END alpha=20, copy_X=False, fit_intercept=True, solver=lsqr, tol=0.001;, score=-0.794 total time=   0.0s
# [CV 3/5] END alpha=20, copy_X=False, fit_intercept=True, solver=lsqr, tol=0.001;, score=-0.703 total time=   0.0s
# [CV 4/5] END alpha=20, copy_X=False, fit_intercept=True, solver=lsqr, tol=0.001;, score=-0.673 total time=   0.0s
# [CV 5/5] END alpha=20, copy_X=False, fit_intercept=True, solver=lsqr, tol=0.001;, score=-0.673 total time=   0.0s
# [CV 1/5] END alpha=2, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.01;, score=-0.843 total time=   0.0s
# [CV 2/5] END alpha=2, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.01;, score=-0.936 total time=   0.0s
# [CV 3/5] END alpha=2, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.01;, score=-0.879 total time=   0.0s
# [CV 4/5] END alpha=2, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.01;, score=-0.834 total time=   0.0s
# [CV 5/5] END alpha=2, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.01;, score=-1.481 total time=   0.0s
# [CV 1/5] END alpha=100, copy_X=False, fit_intercept=True, solver=sag, tol=0.0001;, score=-0.682 total time=   0.0s
# [CV 2/5] END alpha=100, copy_X=False, fit_intercept=True, solver=sag, tol=0.0001;, score=-0.790 total time=   0.0s
# [CV 1/5] END alpha=1, copy_X=False, fit_intercept=True, solver=sag, tol=1;, score=-1.980 total time=   0.0s
# [CV 2/5] END alpha=1, copy_X=False, fit_intercept=True, solver=sag, tol=1;, score=-1.434 total time=   0.0s
# [CV 3/5] END alpha=1, copy_X=False, fit_intercept=True, solver=sag, tol=1;, score=-1.125 total time=   0.0s
# [CV 3/5] END alpha=100, copy_X=False, fit_intercept=True, solver=sag, tol=0.0001;, score=-0.702 total time=   0.1s
# [CV 4/5] END alpha=1, copy_X=False, fit_intercept=True, solver=sag, tol=1;, score=-2.100 total time=   0.0s
# [CV 5/5] END alpha=1, copy_X=False, fit_intercept=True, solver=sag, tol=1;, score=-0.911 total time=   0.0s
# [CV 1/5] END alpha=10, copy_X=False, fit_intercept=False, solver=saga, tol=10;, score=-1.136 total time=   0.0s
# [CV 2/5] END alpha=10, copy_X=False, fit_intercept=False, solver=saga, tol=10;, score=-2.037 total time=   0.0s
# [CV 4/5] END alpha=100, copy_X=False, fit_intercept=True, solver=sag, tol=0.0001;, score=-0.667 total time=   0.1s
# [CV 3/5] END alpha=10, copy_X=False, fit_intercept=False, solver=saga, tol=10;, score=-1.501 total time=   0.0s
# [CV 4/5] END alpha=10, copy_X=False, fit_intercept=False, solver=saga, tol=10;, score=-1.173 total time=   0.0s
# [CV 5/5] END alpha=10, copy_X=False, fit_intercept=False, solver=saga, tol=10;, score=-1.403 total time=   0.0s
# [CV 1/5] END alpha=1, copy_X=True, fit_intercept=False, solver=svd, tol=0.01;, score=-0.690 total time=   0.0s
# [CV 2/5] END alpha=1, copy_X=True, fit_intercept=False, solver=svd, tol=0.01;, score=-0.790 total time=   0.0s
# [CV 3/5] END alpha=1, copy_X=True, fit_intercept=False, solver=svd, tol=0.01;, score=-0.707 total time=   0.0s
# [CV 4/5] END alpha=1, copy_X=True, fit_intercept=False, solver=svd, tol=0.01;, score=-0.671 total time=   0.0s
# [CV 1/5] END alpha=100, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=1;, score=-2.135 total time=   0.0s
# [CV 2/5] END alpha=100, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=1;, score=-2.432 total time=   0.0s
# [CV 5/5] END alpha=1, copy_X=True, fit_intercept=False, solver=svd, tol=0.01;, score=-0.666 total time=   0.0s
# [CV 3/5] END alpha=100, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=1;, score=-1.876 total time=   0.0s
# [CV 4/5] END alpha=100, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=1;, score=-1.893 total time=   0.0s
# [CV 5/5] END alpha=100, copy_X=False, fit_intercept=True, solver=sag, tol=0.0001;, score=-0.661 total time=   0.2s
# [CV 5/5] END alpha=100, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=1;, score=-1.890 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-0.962 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-0.925 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-0.925 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.003 total time=   0.0s
# [CV 1/5] END alpha=5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.001;, score=-0.684 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-0.989 total time=   0.0s
# [CV 2/5] END alpha=5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.001;, score=-0.794 total time=   0.0s
# [CV 3/5] END alpha=5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.001;, score=-0.703 total time=   0.0s
# [CV 4/5] END alpha=5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.001;, score=-0.673 total time=   0.0s
# [CV 5/5] END alpha=5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.001;, score=-0.673 total time=   0.0s
# [CV 2/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sag, tol=10;, score=-1.370 total time=   0.0s
# [CV 1/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sag, tol=10;, score=-1.198 total time=   0.0s
# [CV 3/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sag, tol=10;, score=-1.378 total time=   0.0s
# [CV 4/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sag, tol=10;, score=-2.601 total time=   0.0s
# [CV 1/5] END alpha=20, copy_X=True, fit_intercept=False, solver=saga, tol=10;, score=-1.164 total time=   0.0s
# [CV 5/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sag, tol=10;, score=-1.142 total time=   0.0s
# [CV 2/5] END alpha=20, copy_X=True, fit_intercept=False, solver=saga, tol=10;, score=-2.168 total time=   0.0s
# [CV 3/5] END alpha=20, copy_X=True, fit_intercept=False, solver=saga, tol=10;, score=-1.437 total time=   0.0s
# [CV 5/5] END alpha=20, copy_X=True, fit_intercept=False, solver=saga, tol=10;, score=-1.147 total time=   0.0s
# [CV 4/5] END alpha=20, copy_X=True, fit_intercept=False, solver=saga, tol=10;, score=-1.322 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=saga, tol=0.001;, score=-0.682 total time=   0.0s
# [CV 1/5] END alpha=1, copy_X=False, fit_intercept=False, solver=lsqr, tol=0.001;, score=-0.693 total time=   0.0s
# [CV 2/5] END alpha=1, copy_X=False, fit_intercept=False, solver=lsqr, tol=0.001;, score=-0.795 total time=   0.0s
# [CV 5/5] END alpha=1, copy_X=False, fit_intercept=False, solver=lsqr, tol=0.001;, score=-0.690 total time=   0.0s
# [CV 3/5] END alpha=1, copy_X=False, fit_intercept=False, solver=lsqr, tol=0.001;, score=-0.722 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=saga, tol=0.001;, score=-0.790 total time=   0.0s
# [CV 1/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=1;, score=-0.690 total time=   0.0s
# [CV 2/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=1;, score=-0.790 total time=   0.0s
# [CV 4/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=1;, score=-0.671 total time=   0.0s
# [CV 4/5] END alpha=1, copy_X=False, fit_intercept=False, solver=lsqr, tol=0.001;, score=-0.700 total time=   0.0s
# [CV 3/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=1;, score=-0.707 total time=   0.0s
# [CV 5/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=1;, score=-0.666 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=True, fit_intercept=False, solver=auto, tol=100;, score=-0.707 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=True, fit_intercept=False, solver=auto, tol=100;, score=-0.690 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=True, fit_intercept=False, solver=auto, tol=100;, score=-0.671 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=True, fit_intercept=False, solver=auto, tol=100;, score=-0.790 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=True, fit_intercept=False, solver=auto, tol=100;, score=-0.666 total time=   0.0s
# [CV 2/5] END alpha=0.1, copy_X=True, fit_intercept=False, solver=cholesky, tol=0.01;, score=-0.790 total time=   0.0s
# [CV 1/5] END alpha=0.1, copy_X=True, fit_intercept=False, solver=cholesky, tol=0.01;, score=-0.690 total time=   0.0s
# [CV 3/5] END alpha=0.1, copy_X=True, fit_intercept=False, solver=cholesky, tol=0.01;, score=-0.707 total time=   0.0s
# [CV 1/5] END alpha=20, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.001;, score=-0.695 total time=   0.0s
# [CV 4/5] END alpha=0.1, copy_X=True, fit_intercept=False, solver=cholesky, tol=0.01;, score=-0.671 total time=   0.0s
# [CV 2/5] END alpha=20, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.001;, score=-0.797 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=saga, tol=0.001;, score=-0.701 total time=   0.1s
# [CV 5/5] END alpha=0.1, copy_X=True, fit_intercept=False, solver=cholesky, tol=0.01;, score=-0.666 total time=   0.0s
# [CV 3/5] END alpha=20, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.001;, score=-0.722 total time=   0.0s
# [CV 4/5] END alpha=20, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.001;, score=-0.700 total time=   0.0s
# [CV 5/5] END alpha=20, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.001;, score=-0.771 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=saga, tol=0.001;, score=-0.669 total time=   0.1s
# [CV 1/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.1;, score=-0.803 total time=   0.0s[CV 4/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.1;, score=-1.301 total time=   0.0s
#
# [CV 2/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.1;, score=-0.922 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.1;, score=-0.803 total time=   0.0s
# [CV 3/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=0.0001;, score=-0.703 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.1;, score=-1.358 total time=   0.0s
# [CV 1/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=0.0001;, score=-0.690 total time=   0.0s
# [CV 2/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=0.0001;, score=-0.790 total time=   0.0s
# [CV 4/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=0.0001;, score=-0.677 total time=   0.0s
# [CV 5/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=0.0001;, score=-0.677 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=svd, tol=0.0001;, score=-0.683 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=svd, tol=0.0001;, score=-0.790 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=svd, tol=0.0001;, score=-0.703 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=svd, tol=0.0001;, score=-0.667 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=svd, tol=0.0001;, score=-0.661 total time=   0.0s
# [CV 1/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=100;, score=-1.428 total time=   0.0s
# [CV 2/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=100;, score=-1.644 total time=   0.0s
# [CV 3/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=100;, score=-1.356 total time=   0.0s
# [CV 4/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=100;, score=-1.304 total time=   0.0s
# [CV 5/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=100;, score=-1.257 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=saga, tol=0.001;, score=-0.664 total time=   0.1s
# RandomizedSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#                    estimator=Ridge(), n_iter=25, n_jobs=-1,
#                    param_distributions={'alpha': [0.1, 0.5, 1, 2, 5, 10, 20, 50,
#                                                   100],
#                                         'copy_X': [True, False],
#                                         'fit_intercept': [True, False],
#                                         'solver': ['auto', 'svd', 'cholesky',
#                                                    'lsqr', 'sparse_cg', 'sag',
#                                                    'saga'],
#                                         'tol': [0.0001, 0.001, 0.01, 0.1, 1, 10,
#                                                 100]},
#                    random_state=42,
#                    scoring=make_scorer(mean_absolute_scaled_error, greater_is_better=False),
#                    verbose=3)

# %%
print('Best Score: %s' % search.best_score_)
print('Best Hyperparameters: %s' % search.best_params_)
print('Best Model: %s' % search.best_estimator_)
print('Best Index: %s' % search.best_index_)
print('CV Results: %s' % search.cv_results_)
print('Refit Time: %s' % search.refit_time_)
print('Scorer: %s' % search.scorer_)
# Out:
# Best Score: -0.7005510619401708
# Best Hyperparameters: {'tol': 0.0001, 'solver': 'sag', 'fit_intercept': True, 'copy_X': False, 'alpha': 100}
# Best Model: Ridge(alpha=100, copy_X=False, solver='sag')
# Best Index: 6
# CV Results: {'mean_fit_time': array([0.01016808, 0.00840225, 0.00662584, 0.00667739, 0.00524888,
#        0.00472946, 0.06880178, 0.00533266, 0.00522919, 0.00620418,
#        0.00443854, 0.00528607, 0.00500822, 0.00508757, 0.00533662,
#        0.06995425, 0.00525436, 0.00682778, 0.00415025, 0.0041326 ,
#        0.00434961, 0.00440946, 0.00486388, 0.00655627, 0.00447912]), 'std_fit_time': array([0.00423789, 0.00292339, 0.00190096, 0.0028275 , 0.00139478,
#        0.00140945, 0.05173603, 0.00208446, 0.00179744, 0.00215818,
#        0.00144728, 0.00177761, 0.00136393, 0.00155545, 0.00172716,
#        0.04909538, 0.00288172, 0.00288872, 0.00129436, 0.00118103,
#        0.00144392, 0.00137838, 0.0016189 , 0.00208699, 0.00127247]), 'mean_score_time': array([0.00254474, 0.00282397, 0.00209551, 0.00219755, 0.00231032,
#        0.00225906, 0.0022193 , 0.00192957, 0.00195861, 0.00202918,
#        0.0020504 , 0.0020586 , 0.00211606, 0.00221024, 0.00215597,
#        0.00197945, 0.00224996, 0.00189376, 0.00179682, 0.00187254,
#        0.00192938, 0.0020082 , 0.0021596 , 0.00210314, 0.00199761]), 'std_score_time': array([8.66920045e-04, 8.22264535e-04, 1.02122267e-04, 2.14562225e-04,
#        9.90123855e-05, 9.56381769e-05, 2.63646046e-04, 2.01890082e-04,
#        1.29600883e-04, 1.11278510e-04, 2.70668497e-04, 1.05890879e-04,
#        8.52327713e-05, 2.82861940e-04, 1.01954141e-04, 2.12889747e-04,
#        7.42255065e-04, 8.85535518e-05, 1.06721823e-04, 1.56477585e-04,
#        1.72387125e-04, 1.12609111e-04, 1.07083230e-04, 7.30975033e-05,
#        2.86825086e-04]), 'param_tol': masked_array(data=[0.001, 0.01, 0.1, 100, 0.001, 0.01, 0.0001, 1, 10,
#                    0.01, 1, 100, 0.001, 10, 10, 0.001, 0.001, 1, 100,
#                    0.01, 0.001, 0.1, 0.0001, 0.0001, 100],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_solver': masked_array(data=['sparse_cg', 'cholesky', 'svd', 'saga', 'lsqr',
#                    'sparse_cg', 'sag', 'sag', 'saga', 'svd', 'sparse_cg',
#                    'saga', 'lsqr', 'sag', 'saga', 'saga', 'lsqr', 'svd',
#                    'auto', 'cholesky', 'sparse_cg', 'lsqr', 'sparse_cg',
#                    'svd', 'sparse_cg'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_fit_intercept': masked_array(data=[True, True, False, True, True, False, True, True,
#                    False, False, False, True, True, False, False, True,
#                    False, False, False, False, False, True, False, True,
#                    True],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_copy_X': masked_array(data=[False, True, False, False, False, False, False, False,
#                    False, True, True, False, True, True, True, True,
#                    False, False, True, True, False, True, True, True,
#                    False],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_alpha': masked_array(data=[10, 0.5, 100, 50, 20, 2, 100, 1, 10, 1, 100, 0.5, 5, 5,
#                    20, 0.5, 1, 100, 0.5, 0.1, 20, 0.5, 5, 0.5, 10],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'params': [{'tol': 0.001, 'solver': 'sparse_cg', 'fit_intercept': True, 'copy_X': False, 'alpha': 10}, {'tol': 0.01, 'solver': 'cholesky', 'fit_intercept': True, 'copy_X': True, 'alpha': 0.5}, {'tol': 0.1, 'solver': 'svd', 'fit_intercept': False, 'copy_X': False, 'alpha': 100}, {'tol': 100, 'solver': 'saga', 'fit_intercept': True, 'copy_X': False, 'alpha': 50}, {'tol': 0.001, 'solver': 'lsqr', 'fit_intercept': True, 'copy_X': False, 'alpha': 20}, {'tol': 0.01, 'solver': 'sparse_cg', 'fit_intercept': False, 'copy_X': False, 'alpha': 2}, {'tol': 0.0001, 'solver': 'sag', 'fit_intercept': True, 'copy_X': False, 'alpha': 100}, {'tol': 1, 'solver': 'sag', 'fit_intercept': True, 'copy_X': False, 'alpha': 1}, {'tol': 10, 'solver': 'saga', 'fit_intercept': False, 'copy_X': False, 'alpha': 10}, {'tol': 0.01, 'solver': 'svd', 'fit_intercept': False, 'copy_X': True, 'alpha': 1}, {'tol': 1, 'solver': 'sparse_cg', 'fit_intercept': False, 'copy_X': True, 'alpha': 100}, {'tol': 100, 'solver': 'saga', 'fit_intercept': True, 'copy_X': False, 'alpha': 0.5}, {'tol': 0.001, 'solver': 'lsqr', 'fit_intercept': True, 'copy_X': True, 'alpha': 5}, {'tol': 10, 'solver': 'sag', 'fit_intercept': False, 'copy_X': True, 'alpha': 5}, {'tol': 10, 'solver': 'saga', 'fit_intercept': False, 'copy_X': True, 'alpha': 20}, {'tol': 0.001, 'solver': 'saga', 'fit_intercept': True, 'copy_X': True, 'alpha': 0.5}, {'tol': 0.001, 'solver': 'lsqr', 'fit_intercept': False, 'copy_X': False, 'alpha': 1}, {'tol': 1, 'solver': 'svd', 'fit_intercept': False, 'copy_X': False, 'alpha': 100}, {'tol': 100, 'solver': 'auto', 'fit_intercept': False, 'copy_X': True, 'alpha': 0.5}, {'tol': 0.01, 'solver': 'cholesky', 'fit_intercept': False, 'copy_X': True, 'alpha': 0.1}, {'tol': 0.001, 'solver': 'sparse_cg', 'fit_intercept': False, 'copy_X': False, 'alpha': 20}, {'tol': 0.1, 'solver': 'lsqr', 'fit_intercept': True, 'copy_X': True, 'alpha': 0.5}, {'tol': 0.0001, 'solver': 'sparse_cg', 'fit_intercept': False, 'copy_X': True, 'alpha': 5}, {'tol': 0.0001, 'solver': 'svd', 'fit_intercept': True, 'copy_X': True, 'alpha': 0.5}, {'tol': 100, 'solver': 'sparse_cg', 'fit_intercept': True, 'copy_X': False, 'alpha': 10