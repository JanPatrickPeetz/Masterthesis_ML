# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import ParameterGrid

# %%
# Set parameters for linear regression

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 500, num = 10)]
# Number of features to consider at every split
max_features = [1.0, 'sqrt', 'log2']
# Maximum number of levels in tree
#max_depth = [int(x) for x in np.linspace(10, 110, num = 5)]
#max_depth.append(None)
# Minimum number of samples required to split a node
#min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

warm_start = [True, False]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               #'max_depth': max_depth,
               #'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap,
               'warm_start': warm_start}

grid = ParameterGrid(random_grid)
cnt = 0
for p in grid:
    cnt = cnt+1

print('Total Possible Models',cnt)
# Out:
# Total Possible Models 360

# %%
#Define MASE Metric
def mean_absolute_scaled_error(y_true, y_pred):
    mase=0
    # Define numerator as the forecast error
    numerator = (np.abs(y_true - y_pred))

    # Define denominator as the mean absolute error of the in-sample one-step naive forecast
    y_true_ohne_1 = y_true[1:].reset_index(drop=True)
    y_true_ohne_ende = y_true[:-1].reset_index(drop=True)
    denominator = np.mean(np.abs(y_true_ohne_1 - y_true_ohne_ende))

    mase = np.mean(np.abs(numerator / denominator))

    return mase

scorer_mase= make_scorer(mean_absolute_scaled_error, greater_is_better=False)

# %%
# Load the data
data = pd.read_parquet('/Users/paddy/Documents/GitHub/Masterthesis_ML/data/03_032022_032023_taxi_rides.parquet')

# Convert the date column to datetime
data['date'] = pd.to_datetime(data['date']) #,format='%d/%m/%y %H:%M:%S').dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
#Feature engineering
# Create a new column for the time
data['time'] = [x for x in range(0, len(data))]

# Create the lagged features
lags = 24 + 1 # 24 hours lag + 1

# Create the lagged features
for i in range(1, lags):
    data['lag' + str(i)] = data['count'].shift(i)

# Drop the first three rows
data = data.dropna().reset_index(drop=True)

# Define the feature columns and the target column
feature_cols = [ f'lag{i}' for i in range(1, lags)]
target_col = 'y'

# Drop nan values
data = data.dropna()

# Rename column count to y
data = data.rename(columns={'count': 'y'})

# %%
# Set y to the last column
cols = list(data.columns.values) #Make a list of all of the columns in the df
cols.pop(cols.index('y')) #Remove y from list
data = data[cols+['y']] #Create new dataframe with columns in the order you want

# drop the date column
train_data = np.delete(data, 0, 1) 

# Split the data into X and y
X_train, y_train = train_data[:, :-1], train_data[:, -1]

# %%
#vgl: https://lightrun.com/answers/scikit-learn-scikit-learn-grid_search-feeding-parameters-to-scorer-functions

# X and y to pandas dataframe
X_train = pd.DataFrame(X_train)
y_train = pd.Series(y_train)

# %%
# Set Cross Validation to 5 iterations
tscv = TimeSeriesSplit(n_splits=5)

# %%
# Instantiate model
model = RandomForestRegressor()

search = RandomizedSearchCV(estimator = model, 
                            param_distributions = random_grid, 
                            n_iter = 25, 
                            cv = tscv,
                            refit=True, 
                            verbose=3, 
                            random_state=42, 
                            n_jobs = -1, 
                            scoring=scorer_mase, #make_scorer(scorer_mase, greater_is_better=True), #'neg_root_mean_squared_error', #
                            error_score=np.nan)

# %%
# Fit the random search model
search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.643 total time=   0.8s
# [CV 2/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.793 total time=   1.8s
# [CV 1/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=118, warm_start=True;, score=-0.885 total time=   2.2s
# [CV 3/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.659 total time=   2.6s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=118, warm_start=False;, score=-0.654 total time=   0.6s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=118, warm_start=False;, score=-0.770 total time=   1.1s
# [CV 4/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.635 total time=   3.7s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=118, warm_start=False;, score=-0.653 total time=   1.9s
# [CV 2/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=118, warm_start=True;, score=-0.962 total time=   5.1s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=64, warm_start=True;, score=-0.670 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=64, warm_start=True;, score=-0.796 total time=   0.7s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=118, warm_start=False;, score=-0.642 total time=   2.3s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=64, warm_start=True;, score=-0.664 total time=   1.1s
# [CV 5/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.607 total time=   4.6s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=64, warm_start=True;, score=-0.661 total time=   1.4s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=118, warm_start=False;, score=-0.603 total time=   3.0s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=64, warm_start=True;, score=-0.613 total time=   1.6s
# [CV 3/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=118, warm_start=True;, score=-0.836 total time=   8.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=2, n_estimators=336, warm_start=True;, score=-0.658 total time=   1.8s
# [CV 4/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=118, warm_start=True;, score=-0.785 total time=  10.6s
# [CV 1/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.641 total time=   5.5s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=2, n_estimators=336, warm_start=True;, score=-0.776 total time=   3.5s
# [CV 5/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=118, warm_start=True;, score=-0.798 total time=  13.6s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=2, n_estimators=336, warm_start=True;, score=-0.654 total time=   5.6s
# [CV 2/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.780 total time=  11.3s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=2, n_estimators=336, warm_start=True;, score=-0.642 total time=   7.4s
# [CV 1/5] END bootstrap=True, max_features=1.0, min_samples_leaf=1, n_estimators=391, warm_start=False;, score=-0.658 total time=   5.9s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=2, n_estimators=336, warm_start=True;, score=-0.602 total time=   9.3s
# [CV 3/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.653 total time=  17.2s
# [CV 1/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.642 total time=   5.2s
# [CV 2/5] END bootstrap=True, max_features=1.0, min_samples_leaf=1, n_estimators=391, warm_start=False;, score=-0.803 total time=  12.8s
# [CV 4/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.630 total time=  23.8s
# [CV 2/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.782 total time=  10.9s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=1, n_estimators=227, warm_start=True;, score=-0.667 total time=   1.2s
# [CV 3/5] END bootstrap=True, max_features=1.0, min_samples_leaf=1, n_estimators=391, warm_start=False;, score=-0.672 total time=  19.9s
# [CV 5/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.606 total time=  30.8s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=1, n_estimators=227, warm_start=True;, score=-0.785 total time=   2.8s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=1, n_estimators=227, warm_start=True;, score=-0.660 total time=   4.7s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=118, warm_start=True;, score=-0.675 total time=   0.5s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=118, warm_start=True;, score=-0.787 total time=   1.1s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=1, n_estimators=227, warm_start=True;, score=-0.655 total time=   5.9s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=118, warm_start=True;, score=-0.663 total time=   1.3s
# [CV 3/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.651 total time=  17.7s
# [CV 1/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=2, n_estimators=64, warm_start=True;, score=-0.663 total time=   0.2s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=118, warm_start=True;, score=-0.653 total time=   1.6s
# [CV 2/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=2, n_estimators=64, warm_start=True;, score=-0.781 total time=   0.4s
# [CV 3/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=2, n_estimators=64, warm_start=True;, score=-0.659 total time=   0.7s
# [CV 4/5] END bootstrap=True, max_features=1.0, min_samples_leaf=1, n_estimators=391, warm_start=False;, score=-0.650 total time=  27.8s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=1, n_estimators=227, warm_start=True;, score=-0.605 total time=   7.8s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=118, warm_start=True;, score=-0.612 total time=   2.0s
# [CV 4/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=2, n_estimators=64, warm_start=True;, score=-0.655 total time=   1.0s
# [CV 5/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=2, n_estimators=64, warm_start=True;, score=-0.609 total time=   1.2s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=391, warm_start=True;, score=-0.655 total time=   1.5s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=391, warm_start=True;, score=-0.769 total time=   2.9s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=391, warm_start=True;, score=-0.654 total time=   4.4s
# [CV 4/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.629 total time=  24.3s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=391, warm_start=True;, score=-0.641 total time=   5.9s
# [CV 1/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=282, warm_start=True;, score=-0.931 total time=   6.1s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=391, warm_start=True;, score=-0.603 total time=   7.7s
# [CV 5/5] END bootstrap=True, max_features=1.0, min_samples_leaf=1, n_estimators=391, warm_start=False;, score=-0.619 total time=  36.7s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=500, warm_start=False;, score=-0.658 total time=   2.1s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=500, warm_start=False;, score=-0.775 total time=   4.2s
# [CV 5/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.606 total time=  31.4s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=500, warm_start=False;, score=-0.654 total time=   6.6s
# [CV 2/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=282, warm_start=True;, score=-1.055 total time=  13.3s
# [CV 1/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=4, n_estimators=500, warm_start=False;, score=-0.651 total time=   1.5s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=500, warm_start=False;, score=-0.646 total time=   8.9s
# [CV 2/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=4, n_estimators=500, warm_start=False;, score=-0.768 total time=   3.1s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=173, warm_start=True;, score=-0.672 total time=   0.7s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=173, warm_start=True;, score=-0.785 total time=   1.3s
# [CV 3/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=4, n_estimators=500, warm_start=False;, score=-0.650 total time=   5.1s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=173, warm_start=True;, score=-0.658 total time=   2.0s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=173, warm_start=True;, score=-0.661 total time=   2.6s
# [CV 4/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=4, n_estimators=500, warm_start=False;, score=-0.642 total time=   6.8s
# [CV 1/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=64, warm_start=False;, score=-0.933 total time=   1.5s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=500, warm_start=False;, score=-0.603 total time=  12.5s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=173, warm_start=True;, score=-0.608 total time=   3.4s
# [CV 3/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=282, warm_start=True;, score=-0.880 total time=  22.5s
# [CV 5/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=4, n_estimators=500, warm_start=False;, score=-0.605 total time=   8.6s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=10, warm_start=True;, score=-0.711 total time=   0.1s
# [CV 2/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=64, warm_start=False;, score=-1.053 total time=   3.3s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=10, warm_start=True;, score=-0.840 total time=   0.1s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=10, warm_start=True;, score=-0.683 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=10, warm_start=True;, score=-0.683 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=10, warm_start=True;, score=-0.641 total time=   0.3s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=500, warm_start=False;, score=-0.664 total time=   1.9s
# [CV 3/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=64, warm_start=False;, score=-0.882 total time=   5.1s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=500, warm_start=False;, score=-0.783 total time=   3.7s
# [CV 4/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=64, warm_start=False;, score=-0.846 total time=   7.0s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.658 total time=   1.7s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=500, warm_start=False;, score=-0.660 total time=   5.6s
# [CV 5/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=64, warm_start=False;, score=-0.848 total time=   8.7s
# [CV 4/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=282, warm_start=True;, score=-0.842 total time=  29.9s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_leaf=2, n_estimators=10, warm_start=True;, score=-0.692 total time=   0.0s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.771 total time=   3.5s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_leaf=2, n_estimators=10, warm_start=True;, score=-0.799 total time=   0.1s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_leaf=2, n_estimators=10, warm_start=True;, score=-0.696 total time=   0.1s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_leaf=2, n_estimators=10, warm_start=True;, score=-0.686 total time=   0.2s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_leaf=2, n_estimators=10, warm_start=True;, score=-0.646 total time=   0.2s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=500, warm_start=False;, score=-0.657 total time=   7.2s
# [CV 1/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.885 total time=   1.2s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.652 total time=   5.3s
# [CV 2/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.962 total time=   2.7s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=118, warm_start=True;, score=-0.659 total time=   0.6s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=500, warm_start=False;, score=-0.610 total time=   9.4s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.643 total time=   7.3s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=118, warm_start=True;, score=-0.776 total time=   1.1s
# [CV 3/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.836 total time=   4.6s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=118, warm_start=True;, score=-0.654 total time=   1.7s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=118, warm_start=True;, score=-0.642 total time=   2.3s
# [CV 4/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.786 total time=   6.1s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=118, warm_start=True;, score=-0.603 total time=   3.1s
# [CV 5/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=282, warm_start=True;, score=-0.849 total time=  38.3s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.604 total time=   9.6s
# [CV 5/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.797 total time=   7.9s
# [CV 1/5] END bootstrap=True, max_features=1.0, min_samples_leaf=2, n_estimators=336, warm_start=False;, score=-0.650 total time=   5.4s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.653 total time=   2.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.770 total time=   4.3s
# [CV 2/5] END bootstrap=True, max_features=1.0, min_samples_leaf=2, n_estimators=336, warm_start=False;, score=-0.791 total time=  10.6s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.647 total time=   6.4s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.636 total time=   8.4s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.601 total time=  10.1s
# [CV 3/5] END bootstrap=True, max_features=1.0, min_samples_leaf=2, n_estimators=336, warm_start=False;, score=-0.659 total time=  14.9s
# [CV 4/5] END bootstrap=True, max_features=1.0, min_samples_leaf=2, n_estimators=336, warm_start=False;, score=-0.636 total time=  18.4s
# [CV 5/5] END bootstrap=True, max_features=1.0, min_samples_leaf=2, n_estimators=336, warm_start=False;, score=-0.609 total time=  22.7s
# RandomizedSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#                    estimator=RandomForestRegressor(), n_iter=25, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_features': [1.0, 'sqrt', 'log2'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'n_estimators': [10, 64, 118, 173, 227,
#                                                          282, 336, 391, 445,
#                                                          500],
#                                         'warm_start': [True, False]},
#                    random_state=42,
#                    scoring=make_scorer(mean_absolute_scaled_error, greater_is_better=False),
#                    verbose=3)

# %%
print('Best Score: %s' % search.best_score_)
print('Best Hyperparameters: %s' % search.best_params_)
print('Best Model: %s' % search.best_estimator_)
print('Best Index: %s' % search.best_index_)
print('CV Results: %s' % search.cv_results_)
print('Refit Time: %s' % search.refit_time_)
print('Scorer: %s' % search.scorer_)
# Out:
# Best Score: -0.6612663279877624
# Best Hyperparameters: {'warm_start': False, 'n_estimators': 445, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False}
# Best Model: RandomForestRegressor(bootstrap=False, max_features='sqrt', min_samples_leaf=4,
#                       n_estimators=445)
# Best Index: 24
# CV Results: {'mean_fit_time': array([ 7.91544819,  2.66880755,  1.7380228 ,  1.0101984 , 17.64536071,
#         5.43595762, 20.51510296, 17.816117  ,  4.41006465,  1.25133171,
#         0.69445257,  4.41248879, 21.96753221,  6.7526648 ,  4.91198521,
#         1.94104772,  5.1151792 ,  0.16710296,  5.3948926 ,  5.37081647,
#         0.10340452,  4.50634265,  1.70605836, 14.34639592,  6.20445561]), 'std_fit_time': array([ 3.9775297 ,  1.33571115,  0.81625948,  0.45941634,  8.91308781,
#         2.64157541, 10.83495629,  9.30807393,  2.28309709,  0.50681659,
#         0.3419587 ,  2.18545676, 11.44651661,  3.60535419,  2.50571602,
#         0.94198447,  2.57669453,  0.08113373,  2.57287929,  2.75703891,
#         0.05246068,  2.37901376,  0.87406647,  6.02170771,  2.8049579 ]), 'mean_score_time': array([0.01742835, 0.013869  , 0.02554421, 0.02436762, 0.07700171,
#        0.08825946, 0.09645019, 0.08548508, 0.0675065 , 0.03326507,
#        0.0160543 , 0.07682481, 0.05843978, 0.12118859, 0.09690824,
#        0.04599957, 0.01275349, 0.00476079, 0.15035295, 0.09471135,
#        0.00733585, 0.01187835, 0.0339395 , 0.06076779, 0.08353763]), 'std_score_time': array([0.00723217, 0.00241845, 0.00307806, 0.01146487, 0.01329984,
#        0.01804028, 0.01890927, 0.01604451, 0.0135278 , 0.00347492,
#        0.00236964, 0.01253489, 0.01364799, 0.02107709, 0.02073469,
#        0.00983444, 0.00411728, 0.0010753 , 0.02782096, 0.0089943 ,
#        0.00522149, 0.00484001, 0.0081741 , 0.00956164, 0.00873246]), 'param_warm_start': masked_array(data=[True, True, False, True, True, True, False, False,
#                    True, True, True, True, True, False, False, True,
#                    False, True, False, True, True, True, True, False,
#                    False],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[118, 64, 118, 64, 445, 336, 391, 445, 227, 118, 64,
#                    391, 282, 500, 500, 173, 64, 10, 500, 445, 10, 64, 118,
#                    336, 445],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_min_samples_leaf': masked_array(data=[4, 4, 4, 1, 4, 2, 1, 4, 1, 1, 2, 4, 2, 2, 4, 1, 2, 1,
#                    1, 4, 2, 4, 2, 2, 4],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_max_features': masked_array(data=[1.0, 1.0, 'sqrt', 'log2', 1.0, 'sqrt', 1.0, 1.0,
#                    'sqrt', 'log2', 'sqrt', 'log2', 1.0, 'log2', 'sqrt',
#                    'log2', 1.0, 'log2', 'log2', 'log2', 'log2', 1.0,
#                    'log2', 1.0, 'sqrt'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_bootstrap': masked_array(data=[False, True, False, False, True, False, True, True,
#                    False, True, True, False, False, False, True, True,
#                    False, False, True, False, True, False, False, True,
#                    False],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'params': [{'warm_start': True, 'n_estimators': 118, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': False}, {'warm_start': True, 'n_estimators': 64, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': True}, {'warm_start': False, 'n_estimators': 118, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False}, {'warm_start': True, 'n_estimators': 64, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': True, 'n_estimators': 445, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': True}, {'warm_start': True, 'n_estimators': 336, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False}, {'warm_start': False, 'n_estimators': 391, 'min_samples_leaf': 1, 'max_features': 1.0, 'bootstrap': True}, {'warm_start': False, 'n_estimators': 445, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': True}, {'warm_start': True, 'n_estimators': 227, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}, {'warm_start': True, 'n_estimators': 118, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}, {'warm_start': True, 'n_estimators': 64, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True}, {'warm_start': True, 'n_estimators': 391, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': True, 'n_estimators': 282, 'min_samples_leaf': 2, 'max_features': 1.0, 'bootstrap': False}, {'warm_start': False, 'n_estimators': 500, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': False, 'n_estimators': 500, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': True}, {'warm_start': True, 'n_estimators': 173, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}, {'warm_start': False, 'n_estimators': 64, 'min_samples_leaf': 2, 'max_features': 1.0, 'bootstrap': False}, {'warm_start': True, 'n_estimators': 10, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': False, 'n_estimators': 500, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}, {'warm_start': True, 'n_estimators': 445, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': True, 'n_estimators': 10, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': True}, {'warm_start': True, 'n_estimators': 64, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': False}, {'warm_start': True, 'n_estimators': 118, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': False, 'n_estimators': 336, 'min_samples_leaf': 2, 'max_features': 1.0, 'bootstrap': True}, {'warm_start': False, 'n_estimators': 445, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False}], 'split0_test_score': array([-0.88524299, -0.64251724, -0.65374284, -0.67046198, -0.64113629,
#        -0.65760852, -0.65825984, -0.64221709, -0.66731696, -0.67499808,
#        -0.66330013, -0.65512044, -0.93112142, -0.65802366, -0.65064222,
#        -0.6717282 , -0.93264231, -0.71126254, -0.66370247, -0.6577779 ,
#        -0.69200116, -0.88517536, -0.65948647, -0.64982107, -0.65276424]), 'split1_test_score': array([-0.96212224, -0.79331437, -0.77014812, -0.79611796, -0.78007966,
#        -0.7755229 , -0.80269606, -0.78157946, -0.78547171, -0.78723665,
#        -0.78075089, -0.76908835, -1.05475713, -0.77512607, -0.76814449,
#        -0.78527688, -1.05274694, -0.8397688 , -0.78262794, -0.77056112,
#        -0.79926725, -0.96172551, -0.77562669, -0.79089975, -0.77009522]), 'split2_test_score': array([-0.83569607, -0.65889934, -0.65339997, -0.66388616, -0.65343364,
#        -0.65445087, -0.67190119, -0.65058036, -0.65976755, -0.66306949,
#        -0.65894007, -0.65390276, -0.87992169, -0.6540267 , -0.64957297,
#        -0.65754818, -0.88167748, -0.68291659, -0.65957825, -0.65155298,
#        -0.69631078, -0.83575667, -0.65392944, -0.65899477, -0.64687347]), 'split3_test_score': array([-0.78538317, -0.63533546, -0.64150133, -0.6608193 , -0.63045756,
#        -0.64165773, -0.65036366, -0.62857473, -0.6552154 , -0.65280741,
#        -0.65452065, -0.64060137, -0.84224374, -0.6457828 , -0.64196299,
#        -0.66091587, -0.84625359, -0.68283676, -0.6571469 , -0.64275648,
#        -0.68631904, -0.78569852, -0.64227057, -0.63634544, -0.63589855]), 'split4_test_score': array([-0.79783918, -0.60650748, -0.60260738, -0.61261417, -0.60594409,
#        -0.6023508 , -0.61891965, -0.60647541, -0.60451376, -0.61169751,
#        -0.60895831, -0.60264178, -0.84867078, -0.60333295, -0.60505622,
#        -0.60770066, -0.84798139, -0.64125553, -0.6097131 , -0.60406957,
#        -0.64552202, -0.79690259, -0.60343011, -0.6094328 , -0.60070016]), 'mean_test_score': array([-0.85325673, -0.66731478, -0.66427993, -0.68077992, -0.66221025,
#        -0.66631816, -0.68042808, -0.66188541, -0.67445707, -0.67796183,
#        -0.67329401, -0.66427094, -0.91134295, -0.66725844, -0.66307578,
#        -0.67663396, -0.91226034, -0.71160804, -0.67455373, -0.66534361,
#        -0.70388405, -0.85305173, -0.66694866, -0.66909877, -0.66126633]), 'std_test_score': array([0.06459276, 0.06524085, 0.0561424 , 0.06122045, 0.06097286,
#        0.05803848, 0.06356218, 0.06167849, 0.05975504, 0.05864343,
#        0.05717414, 0.05574284, 0.07829254, 0.05734711, 0.0551151 ,
#        0.05863527, 0.0769102 , 0.06786127, 0.0574967 , 0.05582622,
#        0.05101209, 0.0645449 , 0.05775762, 0.06315379, 0.05733228]), 'rank_test_score': array([23, 11,  6, 19,  3,  8, 18,  2, 14, 17, 13,  5, 24, 10,  4, 16, 25,
#        21, 15,  7, 20, 22,  9, 12,  1], dtype=int32)}
# Refit Time: 9.034083127975464
# Scorer: make_scorer(mean_absolute_scaled_error, greater_is_better=False)
