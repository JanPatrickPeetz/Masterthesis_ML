# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer
from sklearn.linear_model import Ridge

# %%
# Set parameters for linear regression

# ridge parameters for random search
fit_intercept = [True, False]
copy_X = [True, False]
alpha = [0.1, 0.5, 1, 2, 5, 10, 20, 50, 100]
tol = [0.0001, 0.001, 0.01, 0.1, 1, 10, 100]
solver = ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']

# Create the random grid
random_grid = {'fit_intercept': fit_intercept,
                'copy_X': copy_X,
                'alpha': alpha,
                'tol': tol,
                'solver': solver}

# %%
#Define MASE Metric
def mean_absolute_scaled_error(y_true, y_pred):
    mase=0
    # Define numerator as the forecast error
    numerator = (np.abs(y_true - y_pred))

    # Define denominator as the mean absolute error of the in-sample one-step naive forecast
    y_true_ohne_1 = y_true[1:].reset_index(drop=True)
    y_true_ohne_ende = y_true[:-1].reset_index(drop=True)
    denominator = np.mean(np.abs(y_true_ohne_1 - y_true_ohne_ende))

    mase = np.mean(np.abs(numerator / denominator))

    return mase

scorer_mase= make_scorer(mean_absolute_scaled_error, greater_is_better=False)

# %%
# Load the data
data = pd.read_parquet('/Users/paddy/Documents/GitHub/Masterthesis_ML/data/03_15min_dataset.parquet')

# Convert the date column to datetime
data['date'] = pd.to_datetime(data['date']) #,format='%d/%m/%y %H:%M:%S').dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
#Feature engineering
# Create a new column for the time
data['time'] = [x for x in range(0, len(data))]

# Drop nan values
data = data.dropna()

# Rename column count to y
data = data.rename(columns={'count': 'y'})

# %%
# Set y to the last column
cols = list(data.columns.values) #Make a list of all of the columns in the df
cols.pop(cols.index('y')) #Remove y from list
data = data[cols+['y']] #Create new dataframe with columns in the order you want

# Define the feature columns and the target column
feature_cols = ['time']
target_col = 'y'

# drop the date column
train_data = np.delete(data, 0, 1) 

# Split the data into X and y
X_train, y_train = train_data[:, :-1], train_data[:, -1]

# %%
#vgl: https://lightrun.com/answers/scikit-learn-scikit-learn-grid_search-feeding-parameters-to-scorer-functions

# X and y to pandas dataframe
X_train = pd.DataFrame(X_train)
y_train = pd.Series(y_train)

# %%
# Set Cross Validation to 5 iterations
tscv = TimeSeriesSplit(n_splits=5)

# %%
# Instantiate model
model = Ridge()

search = RandomizedSearchCV(estimator = model, 
                               param_distributions = random_grid, 
                               n_iter = 25, 
                               cv = tscv,
                               refit=True, 
                               verbose=3, 
                               random_state=42, 
                               n_jobs = -1, 
                               scoring=scorer_mase, #make_scorer(scorer_mase, greater_is_better=True), #'neg_root_mean_squared_error', #
                               error_score=np.nan)

# %%
# Fit the random search model
search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=0.001;, score=-1.413 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=cholesky, tol=0.01;, score=-1.439 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=cholesky, tol=0.01;, score=-1.396 total time=   0.0s
# [CV 1/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=0.1;, score=-2.504 total time=   0.0s
# [CV 2/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=0.1;, score=-2.209 total time=   0.0s
# [CV 3/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=0.1;, score=-1.978 total time=   0.0s
# [CV 4/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=0.1;, score=-1.848 total time=   0.0s
# [CV 4/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=0.001;, score=-1.439 total time=   0.0s
# [CV 5/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=0.1;, score=-1.670 total time=   0.0s
# [CV 1/5] END alpha=50, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.399 total time=   0.0s
# [CV 2/5] END alpha=50, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-2.061 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=cholesky, tol=0.01;, score=-1.450 total time=   0.0s
# [CV 3/5] END alpha=50, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.512 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=cholesky, tol=0.01;, score=-1.464 total time=   0.0s
# [CV 4/5] END alpha=50, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.507 total time=   0.0s
# [CV 1/5] END alpha=20, copy_X=False, fit_intercept=True, solver=lsqr, tol=0.001;, score=-1.413 total time=   0.0s
# [CV 5/5] END alpha=50, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.400 total time=   0.0s
# [CV 2/5] END alpha=20, copy_X=False, fit_intercept=True, solver=lsqr, tol=0.001;, score=-1.464 total time=   0.0s
# [CV 2/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=0.001;, score=-1.464 total time=   0.0s
# [CV 4/5] END alpha=20, copy_X=False, fit_intercept=True, solver=lsqr, tol=0.001;, score=-1.439 total time=   0.0s
# [CV 3/5] END alpha=20, copy_X=False, fit_intercept=True, solver=lsqr, tol=0.001;, score=-1.450 total time=   0.0s
# [CV 5/5] END alpha=20, copy_X=False, fit_intercept=True, solver=lsqr, tol=0.001;, score=-1.396 total time=   0.0s
# [CV 3/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=0.001;, score=-1.450 total time=   0.0s
# [CV 1/5] END alpha=2, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.01;, score=-2.504 total time=   0.0s
# [CV 4/5] END alpha=2, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.01;, score=-1.848 total time=   0.0s
# [CV 5/5] END alpha=2, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.01;, score=-1.670 total time=   0.0s
# [CV 3/5] END alpha=2, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.01;, score=-1.978 total time=   0.0s
# [CV 2/5] END alpha=2, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.01;, score=-2.209 total time=   0.0s
# [CV 5/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=0.001;, score=-1.396 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=cholesky, tol=0.01;, score=-1.413 total time=   0.0s
# [CV 1/5] END alpha=100, copy_X=False, fit_intercept=True, solver=sag, tol=0.0001;, score=-1.413 total time=   0.0s
# [CV 1/5] END alpha=1, copy_X=False, fit_intercept=True, solver=sag, tol=1;, score=-1.536 total time=   0.0s
# [CV 2/5] END alpha=100, copy_X=False, fit_intercept=True, solver=sag, tol=0.0001;, score=-1.464 total time=   0.0s
# [CV 2/5] END alpha=1, copy_X=False, fit_intercept=True, solver=sag, tol=1;, score=-2.028 total time=   0.0s
# [CV 3/5] END alpha=1, copy_X=False, fit_intercept=True, solver=sag, tol=1;, score=-3.398 total time=   0.0s
# [CV 4/5] END alpha=1, copy_X=False, fit_intercept=True, solver=sag, tol=1;, score=-1.423 total time=   0.0s
# [CV 5/5] END alpha=1, copy_X=False, fit_intercept=True, solver=sag, tol=1;, score=-1.389 total time=   0.0s
# [CV 4/5] END alpha=100, copy_X=False, fit_intercept=True, solver=sag, tol=0.0001;, score=-1.439 total time=   0.0s
# [CV 3/5] END alpha=100, copy_X=False, fit_intercept=True, solver=sag, tol=0.0001;, score=-1.450 total time=   0.1s
# [CV 1/5] END alpha=10, copy_X=False, fit_intercept=False, solver=saga, tol=10;, score=-2.093 total time=   0.0s
# [CV 3/5] END alpha=10, copy_X=False, fit_intercept=False, solver=saga, tol=10;, score=-2.839 total time=   0.0s
# [CV 2/5] END alpha=10, copy_X=False, fit_intercept=False, solver=saga, tol=10;, score=-2.374 total time=   0.0s
# [CV 4/5] END alpha=10, copy_X=False, fit_intercept=False, solver=saga, tol=10;, score=-2.135 total time=   0.0s
# [CV 1/5] END alpha=1, copy_X=True, fit_intercept=False, solver=svd, tol=0.01;, score=-2.504 total time=   0.0s
# [CV 5/5] END alpha=10, copy_X=False, fit_intercept=False, solver=saga, tol=10;, score=-1.639 total time=   0.0s
# [CV 2/5] END alpha=1, copy_X=True, fit_intercept=False, solver=svd, tol=0.01;, score=-2.209 total time=   0.0s
# [CV 3/5] END alpha=1, copy_X=True, fit_intercept=False, solver=svd, tol=0.01;, score=-1.978 total time=   0.0s
# [CV 5/5] END alpha=1, copy_X=True, fit_intercept=False, solver=svd, tol=0.01;, score=-1.670 total time=   0.0s
# [CV 4/5] END alpha=1, copy_X=True, fit_intercept=False, solver=svd, tol=0.01;, score=-1.848 total time=   0.0s
# [CV 1/5] END alpha=100, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=1;, score=-1.793 total time=   0.0s
# [CV 5/5] END alpha=100, copy_X=False, fit_intercept=True, solver=sag, tol=0.0001;, score=-1.396 total time=   0.1s
# [CV 2/5] END alpha=100, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=1;, score=-1.823 total time=   0.0s
# [CV 3/5] END alpha=100, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=1;, score=-1.827 total time=   0.0s
# [CV 4/5] END alpha=100, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=1;, score=-1.814 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.428 total time=   0.0s
# [CV 5/5] END alpha=100, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=1;, score=-1.787 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-2.851 total time=   0.0s
# [CV 1/5] END alpha=5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.001;, score=-1.413 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.423 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.433 total time=   0.0s
# [CV 3/5] END alpha=5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.001;, score=-1.450 total time=   0.0s
# [CV 2/5] END alpha=5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.001;, score=-1.464 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.569 total time=   0.0s
# [CV 5/5] END alpha=5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.001;, score=-1.396 total time=   0.0s
# [CV 4/5] END alpha=5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.001;, score=-1.439 total time=   0.0s
# [CV 2/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sag, tol=10;, score=-1.444 total time=   0.0s
# [CV 1/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sag, tol=10;, score=-1.598 total time=   0.0s
# [CV 1/5] END alpha=20, copy_X=True, fit_intercept=False, solver=saga, tol=10;, score=-2.068 total time=   0.0s
# [CV 4/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sag, tol=10;, score=-1.436 total time=   0.0s
# [CV 3/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sag, tol=10;, score=-3.211 total time=   0.0s
# [CV 2/5] END alpha=20, copy_X=True, fit_intercept=False, solver=saga, tol=10;, score=-2.017 total time=   0.0s
# [CV 3/5] END alpha=20, copy_X=True, fit_intercept=False, solver=saga, tol=10;, score=-1.820 total time=   0.0s
# [CV 5/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sag, tol=10;, score=-1.456 total time=   0.0s
# [CV 4/5] END alpha=20, copy_X=True, fit_intercept=False, solver=saga, tol=10;, score=-2.000 total time=   0.0s
# [CV 5/5] END alpha=20, copy_X=True, fit_intercept=False, solver=saga, tol=10;, score=-1.568 total time=   0.0s
# [CV 1/5] END alpha=1, copy_X=False, fit_intercept=False, solver=lsqr, tol=0.001;, score=-2.504 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=saga, tol=0.001;, score=-1.413 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=saga, tol=0.001;, score=-1.464 total time=   0.0s
# [CV 2/5] END alpha=1, copy_X=False, fit_intercept=False, solver=lsqr, tol=0.001;, score=-2.209 total time=   0.0s
# [CV 2/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=1;, score=-2.209 total time=   0.0s
# [CV 5/5] END alpha=1, copy_X=False, fit_intercept=False, solver=lsqr, tol=0.001;, score=-1.670 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=saga, tol=0.001;, score=-1.439 total time=   0.0s
# [CV 3/5] END alpha=1, copy_X=False, fit_intercept=False, solver=lsqr, tol=0.001;, score=-1.978 total time=   0.0s
# [CV 1/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=1;, score=-2.504 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=saga, tol=0.001;, score=-1.450 total time=   0.0s
# [CV 4/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=1;, score=-1.848 total time=   0.0s
# [CV 3/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=1;, score=-1.978 total time=   0.0s
# [CV 4/5] END alpha=1, copy_X=False, fit_intercept=False, solver=lsqr, tol=0.001;, score=-1.848 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=True, fit_intercept=False, solver=auto, tol=100;, score=-1.978 total time=   0.0s
# [CV 5/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=1;, score=-1.670 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=True, fit_intercept=False, solver=auto, tol=100;, score=-2.504 total time=   0.0s
# [CV 2/5] END alpha=0.1, copy_X=True, fit_intercept=False, solver=cholesky, tol=0.01;, score=-2.209 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=True, fit_intercept=False, solver=auto, tol=100;, score=-1.848 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=True, fit_intercept=False, solver=auto, tol=100;, score=-2.209 total time=   0.0s
# [CV 3/5] END alpha=0.1, copy_X=True, fit_intercept=False, solver=cholesky, tol=0.01;, score=-1.978 total time=   0.0s
# [CV 1/5] END alpha=20, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.001;, score=-2.504 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=True, fit_intercept=False, solver=auto, tol=100;, score=-1.670 total time=   0.0s
# [CV 4/5] END alpha=0.1, copy_X=True, fit_intercept=False, solver=cholesky, tol=0.01;, score=-1.848 total time=   0.0s
# [CV 2/5] END alpha=20, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.001;, score=-2.209 total time=   0.0s
# [CV 1/5] END alpha=0.1, copy_X=True, fit_intercept=False, solver=cholesky, tol=0.01;, score=-2.504 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=saga, tol=0.001;, score=-1.396 total time=   0.0s
# [CV 3/5] END alpha=20, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.001;, score=-1.978 total time=   0.0s
# [CV 5/5] END alpha=0.1, copy_X=True, fit_intercept=False, solver=cholesky, tol=0.01;, score=-1.670 total time=   0.0s
# [CV 5/5] END alpha=20, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.001;, score=-1.670 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.1;, score=-1.439 total time=   0.0s
# [CV 4/5] END alpha=20, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.001;, score=-1.848 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.1;, score=-1.413 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.1;, score=-1.396 total time=   0.0s
# [CV 3/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=0.0001;, score=-1.978 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.1;, score=-1.464 total time=   0.0s
# [CV 1/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=0.0001;, score=-2.504 total time=   0.0s
# [CV 4/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=0.0001;, score=-1.848 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=svd, tol=0.0001;, score=-1.464 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.1;, score=-1.450 total time=   0.0s
# [CV 2/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=0.0001;, score=-2.209 total time=   0.0s
# [CV 5/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=0.0001;, score=-1.670 total time=   0.0s
# [CV 1/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=100;, score=-1.399 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=svd, tol=0.0001;, score=-1.413 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=svd, tol=0.0001;, score=-1.450 total time=   0.0s
# [CV 3/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=100;, score=-1.461 total time=   0.0s
# [CV 4/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=100;, score=-1.446 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=svd, tol=0.0001;, score=-1.439 total time=   0.0s
# [CV 5/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=100;, score=-1.395 total time=   0.0s
# [CV 2/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=100;, score=-1.457 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=svd, tol=0.0001;, score=-1.396 total time=   0.0s
# RandomizedSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#                    estimator=Ridge(), n_iter=25, n_jobs=-1,
#                    param_distributions={'alpha': [0.1, 0.5, 1, 2, 5, 10, 20, 50,
#                                                   100],
#                                         'copy_X': [True, False],
#                                         'fit_intercept': [True, False],
#                                         'solver': ['auto', 'svd', 'cholesky',
#                                                    'lsqr', 'sparse_cg', 'sag',
#                                                    'saga'],
#                                         'tol': [0.0001, 0.001, 0.01, 0.1, 1, 10,
#                                                 100]},
#                    random_state=42,
#                    scoring=make_scorer(mean_absolute_scaled_error, greater_is_better=False),
#                    verbose=3)

# %%
print('Best Score: %s' % search.best_score_)
print('Best Hyperparameters: %s' % search.best_params_)
print('Best Model: %s' % search.best_estimator_)
print('Best Index: %s' % search.best_index_)
print('CV Results: %s' % search.cv_results_)
print('Refit Time: %s' % search.refit_time_)
print('Scorer: %s' % search.scorer_)
# Out:
# Best Score: -1.4316765803146283
# Best Hyperparameters: {'tol': 100, 'solver': 'sparse_cg', 'fit_intercept': True, 'copy_X': False, 'alpha': 10}
# Best Model: Ridge(alpha=10, copy_X=False, solver='sparse_cg', tol=100)
# Best Index: 24
# CV Results: {'mean_fit_time': array([0.00945477, 0.00451059, 0.005832  , 0.00628815, 0.00444622,
#        0.00539083, 0.04030061, 0.0044044 , 0.005654  , 0.00387759,
#        0.0040554 , 0.0038651 , 0.00380359, 0.00463285, 0.00443583,
#        0.01651926, 0.00521159, 0.00407228, 0.00282021, 0.0029614 ,
#        0.003615  , 0.00287576, 0.00299373, 0.01157689, 0.00624537]), 'std_fit_time': array([0.00466756, 0.00164902, 0.00264013, 0.00199554, 0.00161303,
#        0.00161835, 0.02124984, 0.0014745 , 0.00178901, 0.00170213,
#        0.00186908, 0.00122092, 0.0010196 , 0.00225785, 0.00141705,
#        0.00882723, 0.00342221, 0.00248375, 0.00109611, 0.0007447 ,
#        0.00121266, 0.00087765, 0.00094903, 0.01291261, 0.00383138]), 'mean_score_time': array([0.00669389, 0.00236497, 0.00286765, 0.00306692, 0.0047092 ,
#        0.00541158, 0.00230756, 0.00224967, 0.00304141, 0.00223866,
#        0.00281019, 0.00250945, 0.00315647, 0.00312905, 0.00281606,
#        0.00243134, 0.0031836 , 0.00279155, 0.0025106 , 0.00213375,
#        0.00242815, 0.00231438, 0.00262103, 0.00299926, 0.00791068]), 'std_score_time': array([3.99348307e-03, 9.52018970e-05, 1.41005491e-03, 9.97340506e-04,
#        2.96712179e-03, 3.62040618e-03, 8.96363305e-05, 2.49992648e-04,
#        1.65991126e-03, 3.26739440e-04, 7.12009429e-04, 6.38873991e-04,
#        8.62263005e-04, 1.11306590e-03, 5.84567440e-04, 3.29951998e-04,
#        1.27472676e-03, 1.18179054e-03, 5.33396925e-04, 2.84862758e-04,
#        6.04488435e-04, 5.19452455e-04, 1.08879381e-03, 6.46950111e-04,
#        9.62735771e-03]), 'param_tol': masked_array(data=[0.001, 0.01, 0.1, 100, 0.001, 0.01, 0.0001, 1, 10,
#                    0.01, 1, 100, 0.001, 10, 10, 0.001, 0.001, 1, 100,
#                    0.01, 0.001, 0.1, 0.0001, 0.0001, 100],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_solver': masked_array(data=['sparse_cg', 'cholesky', 'svd', 'saga', 'lsqr',
#                    'sparse_cg', 'sag', 'sag', 'saga', 'svd', 'sparse_cg',
#                    'saga', 'lsqr', 'sag', 'saga', 'saga', 'lsqr', 'svd',
#                    'auto', 'cholesky', 'sparse_cg', 'lsqr', 'sparse_cg',
#                    'svd', 'sparse_cg'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_fit_intercept': masked_array(data=[True, True, False, True, True, False, True, True,
#                    False, False, False, True, True, False, False, True,
#                    False, False, False, False, False, True, False, True,
#                    True],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_copy_X': masked_array(data=[False, True, False, False, False, False, False, False,
#                    False, True, True, False, True, True, True, True,
#                    False, False, True, True, False, True, True, True,
#                    False],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_alpha': masked_array(data=[10, 0.5, 100, 50, 20, 2, 100, 1, 10, 1, 100, 0.5, 5, 5,
#                    20, 0.5, 1, 100, 0.5, 0.1, 20, 0.5, 5, 0.5, 10],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'params': [{'tol': 0.001, 'solver': 'sparse_cg', 'fit_intercept': True, 'copy_X': False, 'alpha': 10}, {'tol': 0.01, 'solver': 'cholesky', 'fit_intercept': True, 'copy_X': True, 'alpha': 0.5}, {'tol': 0.1, 'solver': 'svd', 'fit_intercept': False, 'copy_X': False, 'alpha': 100}, {'tol': 100, 'solver': 'saga', 'fit_intercept': True, 'copy_X': False, 'alpha': 50}, {'tol': 0.001, 'solver': 'lsqr', 'fit_intercept': True, 'copy_X': False, 'alpha': 20}, {'tol': 0.01, 'solver': 'sparse_cg', 'fit_intercept': False, 'copy_X': False, 'alpha': 2}, {'tol': 0.0001, 'solver': 'sag', 'fit_intercept': True, 'copy_X': False, 'alpha': 100}, {'tol': 1, 'solver': 'sag', 'fit_intercept': True, 'copy_X': False, 'alpha': 1}, {'tol': 10, 'solver': 'saga', 'fit_intercept': False, 'copy_X': False, 'alpha': 10}, {'tol': 0.01, 'solver': 'svd', 'fit_intercept': False, 'copy_X': True, 'alpha': 1}, {'tol': 1, 'solver': 'sparse_cg', 'fit_intercept': False, 'copy_X': True, 'alpha': 100}, {'tol': 100, 'solver': 'saga', 'fit_intercept': True, 'copy_X': False, 'alpha': 0.5}, {'tol': 0.001, 'solver': 'lsqr', 'fit_intercept': True, 'copy_X': True, 'alpha': 5}, {'tol': 10, 'solver': 'sag', 'fit_intercept': False, 'copy_X': True, 'alpha': 5}, {'tol': 10, 'solver': 'saga', 'fit_intercept': False, 'copy_X': True, 'alpha': 20}, {'tol': 0.001, 'solver': 'saga', 'fit_intercept': True, 'copy_X': True, 'alpha': 0.5}, {'tol': 0.001, 'solver': 'lsqr', 'fit_intercept': False, 'copy_X': False, 'alpha': 1}, {'tol': 1, 'solver': 'svd', 'fit_intercept': False, 'copy_X': False, 'alpha': 100}, {'tol': 100, 'solver': 'auto', 'fit_intercept': False, 'copy_X': True, 'alpha': 0.5}, {'tol': 0.01, 'solver': 'cholesky', 'fit_intercept': False, 'copy_X': True, 'alpha': 0.1}, {'tol': 0.001, 'solver': 'sparse_cg', 'fit_intercept': False, 'copy_X': False, 'alpha': 20}, {'tol': 0.1, 'solver': 'lsqr', 'fit_intercept': True, 'copy_X': True, 'alpha': 0.5}, {'tol': 0.0001, 'solver': 'sparse_cg', 'fit_intercept': False, 'copy_X': True, 'alpha': 5}, {'tol': 0.0001, 'solver': 'svd', 'fit_intercept': True, 'copy_X': True, 'alpha': 0.5}, {'tol': 100, 'solver': 'sparse_cg', 'fit_intercept': True, 'copy_X': False, 'alpha': 10