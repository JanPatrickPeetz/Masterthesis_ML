# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import ParameterGrid

# %%
# Set parameters for linear regression

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 500, num = 10)]
# Number of features to consider at every split
max_features = [1.0, 'sqrt', 'log2']
# Maximum number of levels in tree
#max_depth = [int(x) for x in np.linspace(10, 110, num = 5)]
#max_depth.append(None)
# Minimum number of samples required to split a node
#min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

warm_start = [True, False]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               #'max_depth': max_depth,
               #'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap,
               'warm_start': warm_start}

grid = ParameterGrid(random_grid)
cnt = 0
for p in grid:
    cnt = cnt+1

print('Total Possible Models',cnt)
# Out:
# Total Possible Models 360

# %%
#Define MASE Metric
def mean_absolute_scaled_error(y_true, y_pred):
    mase=0
    # Define numerator as the forecast error
    numerator = (np.abs(y_true - y_pred))

    # Define denominator as the mean absolute error of the in-sample one-step naive forecast
    y_true_ohne_1 = y_true[1:].reset_index(drop=True)
    y_true_ohne_ende = y_true[:-1].reset_index(drop=True)
    denominator = np.mean(np.abs(y_true_ohne_1 - y_true_ohne_ende))

    mase = np.mean(np.abs(numerator / denominator))

    return mase

scorer_mase= make_scorer(mean_absolute_scaled_error, greater_is_better=False)

# %%
# Load the data
data = pd.read_parquet('/Users/paddy/Documents/GitHub/Masterthesis_ML/data/03_30min_dataset.parquet')

# Convert the date column to datetime
data['date'] = pd.to_datetime(data['date']) #,format='%d/%m/%y %H:%M:%S').dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
#Feature engineering
# Create a new column for the time
data['time'] = [x for x in range(0, len(data))]

# Drop nan values
data = data.dropna()

# Rename column count to y
data = data.rename(columns={'count': 'y'})

# %%
# Set y to the last column
cols = list(data.columns.values) #Make a list of all of the columns in the df
cols.pop(cols.index('y')) #Remove y from list
data = data[cols+['y']] #Create new dataframe with columns in the order you want

# Define the feature columns and the target column
feature_cols = ['time']
target_col = 'y'

# drop the date column
train_data = np.delete(data, 0, 1) 

# Split the data into X and y
X_train, y_train = train_data[:, :-1], train_data[:, -1]

# %%
#vgl: https://lightrun.com/answers/scikit-learn-scikit-learn-grid_search-feeding-parameters-to-scorer-functions

# X and y to pandas dataframe
X_train = pd.DataFrame(X_train)
y_train = pd.Series(y_train)

# %%
# Set Cross Validation to 5 iterations
tscv = TimeSeriesSplit(n_splits=5)

# %%
# Instantiate model
model = RandomForestRegressor()

search = RandomizedSearchCV(estimator = model, 
                            param_distributions = random_grid, 
                            n_iter = 25, 
                            cv = tscv,
                            refit=True, 
                            verbose=3, 
                            random_state=42, 
                            n_jobs = -1, 
                            scoring=scorer_mase, #make_scorer(scorer_mase, greater_is_better=True), #'neg_root_mean_squared_error', #
                            error_score=np.nan)

# %%
# Fit the random search model
search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-1.564 total time=   0.3s
# [CV 2/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-1.734 total time=   0.8s
# [CV 1/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=118, warm_start=True;, score=-1.487 total time=   1.6s
# [CV 3/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-1.860 total time=   1.7s
# [CV 4/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-1.758 total time=   1.8s
# [CV 2/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=118, warm_start=True;, score=-1.605 total time=   2.3s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=118, warm_start=False;, score=-1.487 total time=   1.4s
# [CV 5/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-1.657 total time=   2.1s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=118, warm_start=False;, score=-1.605 total time=   2.0s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=64, warm_start=True;, score=-1.461 total time=   0.7s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=64, warm_start=True;, score=-1.551 total time=   1.6s
# [CV 3/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=118, warm_start=True;, score=-2.557 total time=   5.8s
# [CV 4/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=118, warm_start=True;, score=-1.664 total time=   6.0s
# [CV 5/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=118, warm_start=True;, score=-1.676 total time=   7.3s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=64, warm_start=True;, score=-3.236 total time=   3.7s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=118, warm_start=False;, score=-2.557 total time=   5.8s
# [CV 1/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-1.539 total time=   2.1s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=118, warm_start=False;, score=-1.664 total time=   6.5s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=64, warm_start=True;, score=-1.732 total time=   3.7s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=64, warm_start=True;, score=-1.891 total time=   4.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=118, warm_start=False;, score=-1.676 total time=   7.1s
# [CV 2/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-1.734 total time=   4.8s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=2, n_estimators=336, warm_start=True;, score=-1.530 total time=   3.6s
# [CV 1/5] END bootstrap=True, max_features=1.0, min_samples_leaf=1, n_estimators=391, warm_start=False;, score=-1.474 total time=   2.3s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=2, n_estimators=336, warm_start=True;, score=-1.733 total time=   6.9s
# [CV 3/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-1.906 total time=   9.9s
# [CV 2/5] END bootstrap=True, max_features=1.0, min_samples_leaf=1, n_estimators=391, warm_start=False;, score=-1.587 total time=   4.9s
# [CV 4/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-1.763 total time=  12.2s
# [CV 5/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-1.604 total time=  14.2s
# [CV 1/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-1.531 total time=   2.3s
# [CV 3/5] END bootstrap=True, max_features=1.0, min_samples_leaf=1, n_estimators=391, warm_start=False;, score=-2.727 total time=   9.6s
# [CV 2/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-1.737 total time=   5.0s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=2, n_estimators=336, warm_start=True;, score=-2.381 total time=  17.5s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=2, n_estimators=336, warm_start=True;, score=-1.491 total time=  18.8s
# [CV 4/5] END bootstrap=True, max_features=1.0, min_samples_leaf=1, n_estimators=391, warm_start=False;, score=-1.619 total time=  12.4s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=1, n_estimators=227, warm_start=True;, score=-1.461 total time=   2.9s
# [CV 3/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-1.888 total time=  10.3s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=1, n_estimators=227, warm_start=True;, score=-1.551 total time=   4.7s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=2, n_estimators=336, warm_start=True;, score=-1.891 total time=  21.7s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=118, warm_start=True;, score=-1.484 total time=   0.7s
# [CV 5/5] END bootstrap=True, max_features=1.0, min_samples_leaf=1, n_estimators=391, warm_start=False;, score=-1.877 total time=  14.6s
# /Users/paddy/Library/Python/3.9/lib/python/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=118, warm_start=True;, score=-1.592 total time=   1.8s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=118, warm_start=True;, score=-2.744 total time=   3.2s
# [CV 1/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=2, n_estimators=64, warm_start=True;, score=-1.511 total time=   0.3s
# [CV 2/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=2, n_estimators=64, warm_start=True;, score=-1.650 total time=   0.8s
# [CV 4/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-1.760 total time=  13.4s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=118, warm_start=True;, score=-1.634 total time=   3.9s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=118, warm_start=True;, score=-1.891 total time=   4.5s
# [CV 3/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=2, n_estimators=64, warm_start=True;, score=-2.357 total time=   1.5s
# [CV 4/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=2, n_estimators=64, warm_start=True;, score=-1.632 total time=   1.9s
# [CV 5/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=2, n_estimators=64, warm_start=True;, score=-1.848 total time=   2.2s
# [CV 5/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-1.600 total time=  15.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=1, n_estimators=227, warm_start=True;, score=-3.236 total time=  13.4s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=391, warm_start=True;, score=-1.487 total time=   4.4s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=1, n_estimators=227, warm_start=True;, score=-1.732 total time=  14.2s
# [CV 1/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=282, warm_start=True;, score=-1.530 total time=   3.5s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=391, warm_start=True;, score=-1.605 total time=   8.0s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=1, n_estimators=227, warm_start=True;, score=-1.891 total time=  16.8s
# [CV 2/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=282, warm_start=True;, score=-1.733 total time=   6.2s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=500, warm_start=False;, score=-1.530 total time=   6.2s
# [CV 3/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=282, warm_start=True;, score=-2.381 total time=  15.8s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=391, warm_start=True;, score=-2.557 total time=  21.1s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=500, warm_start=False;, score=-1.733 total time=  11.5s
# [CV 4/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=282, warm_start=True;, score=-1.491 total time=  17.2s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=391, warm_start=True;, score=-1.664 total time=  22.8s
# [CV 1/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=4, n_estimators=500, warm_start=False;, score=-1.529 total time=   2.5s
# [CV 5/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=282, warm_start=True;, score=-1.891 total time=  19.8s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=391, warm_start=True;, score=-1.676 total time=  26.2s
# [CV 2/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=4, n_estimators=500, warm_start=False;, score=-1.734 total time=   5.6s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=173, warm_start=True;, score=-1.480 total time=   1.0s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=173, warm_start=True;, score=-1.588 total time=   2.1s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=173, warm_start=True;, score=-2.596 total time=   4.3s
# [CV 3/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=4, n_estimators=500, warm_start=False;, score=-1.903 total time=  12.0s
# [CV 1/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=64, warm_start=False;, score=-1.530 total time=   0.7s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=173, warm_start=True;, score=-1.627 total time=   5.7s
# [CV 2/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=64, warm_start=False;, score=-1.733 total time=   1.5s
# [CV 4/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=4, n_estimators=500, warm_start=False;, score=-1.772 total time=  15.4s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=173, warm_start=True;, score=-1.891 total time=   6.4s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=10, warm_start=True;, score=-1.461 total time=   0.1s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=10, warm_start=True;, score=-1.551 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=64, warm_start=False;, score=-2.381 total time=   3.8s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=10, warm_start=True;, score=-3.236 total time=   0.6s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=10, warm_start=True;, score=-1.732 total time=   0.7s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=10, warm_start=True;, score=-1.891 total time=   0.8s
# [CV 4/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=64, warm_start=False;, score=-1.491 total time=   4.4s
# [CV 5/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=64, warm_start=False;, score=-1.891 total time=   4.4s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=500, warm_start=False;, score=-1.481 total time=   3.3s
# [CV 5/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=4, n_estimators=500, warm_start=False;, score=-1.605 total time=  17.6s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=500, warm_start=False;, score=-2.381 total time=  29.1s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=500, warm_start=False;, score=-1.592 total time=   6.8s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-1.487 total time=   5.4s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=500, warm_start=False;, score=-1.491 total time=  31.3s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-1.605 total time=   9.8s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_leaf=2, n_estimators=10, warm_start=True;, score=-1.523 total time=   0.1s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_leaf=2, n_estimators=10, warm_start=True;, score=-1.650 total time=   0.1s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_leaf=2, n_estimators=10, warm_start=True;, score=-2.361 total time=   0.3s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_leaf=2, n_estimators=10, warm_start=True;, score=-1.599 total time=   0.3s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_leaf=2, n_estimators=10, warm_start=True;, score=-1.813 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=500, warm_start=False;, score=-1.891 total time=  35.3s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=500, warm_start=False;, score=-2.666 total time=  14.1s
# [CV 1/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-1.487 total time=   0.8s
# [CV 2/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-1.605 total time=   1.4s
# [CV 3/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-2.557 total time=   3.5s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=500, warm_start=False;, score=-1.621 total time=  16.9s
# [CV 4/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-1.664 total time=   3.9s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=118, warm_start=True;, score=-1.530 total time=   1.6s
# [CV 5/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-1.676 total time=   4.4s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=118, warm_start=True;, score=-1.733 total time=   2.7s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=500, warm_start=False;, score=-1.888 total time=  19.9s
# [CV 1/5] END bootstrap=True, max_features=1.0, min_samples_leaf=2, n_estimators=336, warm_start=False;, score=-1.523 total time=   2.0s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=118, warm_start=True;, score=-2.381 total time=   6.6s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=118, warm_start=True;, score=-1.491 total time=   7.5s
# [CV 2/5] END bootstrap=True, max_features=1.0, min_samples_leaf=2, n_estimators=336, warm_start=False;, score=-1.659 total time=   4.2s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=118, warm_start=True;, score=-1.891 total time=   8.2s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-2.557 total time=  24.6s
# [CV 3/5] END bootstrap=True, max_features=1.0, min_samples_leaf=2, n_estimators=336, warm_start=False;, score=-2.295 total time=   8.7s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-1.487 total time=   5.0s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-1.664 total time=  26.7s
# [CV 4/5] END bootstrap=True, max_features=1.0, min_samples_leaf=2, n_estimators=336, warm_start=False;, score=-1.612 total time=  10.6s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-1.605 total time=   9.1s
# [CV 5/5] END bootstrap=True, max_features=1.0, min_samples_leaf=2, n_estimators=336, warm_start=False;, score=-1.852 total time=  11.7s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-1.676 total time=  29.6s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-2.557 total time=  18.6s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-1.664 total time=  19.6s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-1.676 total time=  21.4s
# RandomizedSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#                    estimator=RandomForestRegressor(), n_iter=25, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_features': [1.0, 'sqrt', 'log2'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'n_estimators': [10, 64, 118, 173, 227,
#                                                          282, 336, 391, 445,
#                                                          500],
#                                         'warm_start': [True, False]},
#                    random_state=42,
#                    scoring=make_scorer(mean_absolute_scaled_error, greater_is_better=False),
#                    verbose=3)

# %%
print('Best Score: %s' % search.best_score_)
print('Best Hyperparameters: %s' % search.best_params_)
print('Best Model: %s' % search.best_estimator_)
print('Best Index: %s' % search.best_index_)
print('CV Results: %s' % search.cv_results_)
print('Refit Time: %s' % search.refit_time_)
print('Scorer: %s' % search.scorer_)
# Out:
# Best Score: -1.7031726904433462
# Best Hyperparameters: {'warm_start': False, 'n_estimators': 445, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': True}
# Best Model: RandomForestRegressor(min_samples_leaf=4, n_estimators=445)
# Best Index: 7
# CV Results: {'mean_fit_time': array([ 4.56512642,  1.33564072,  4.53470068,  2.75272932,  8.56534257,
#        13.61232662,  8.71725612,  9.19941926, 10.34487758,  2.82021141,
#         1.34455919, 16.44911118, 12.43736281, 22.57429056, 10.5765305 ,
#         3.90906258,  2.95720911,  0.47983284, 12.14265604, 19.11779456,
#         0.22459717,  2.78314176,  5.28073359,  7.40969501, 14.66424098]), 'std_fit_time': array([ 2.22666579,  0.67282436,  2.38613861,  1.36425589,  4.53706678,
#         7.09839944,  4.57261431,  4.90413605,  5.51610523,  1.40803862,
#         0.6684837 ,  8.64837811,  6.45885061, 11.60984484,  5.73648489,
#         2.07149762,  1.56075274,  0.24947319,  6.23286944,  9.76886065,
#         0.10363157,  1.436604  ,  2.68332201,  3.76028519,  6.48546597]), 'mean_score_time': array([0.02565794, 0.00984435, 0.0210011 , 0.01525583, 0.04044209,
#        0.07466121, 0.04367523, 0.03665786, 0.04713693, 0.01291466,
#        0.00658803, 0.07643948, 0.06063294, 0.10948701, 0.04438877,
#        0.01886935, 0.01583161, 0.00495291, 0.05796876, 0.09121933,
#        0.00262341, 0.02185516, 0.03052692, 0.03409061, 0.06870427]), 'std_score_time': array([0.02175038, 0.00507452, 0.0150193 , 0.00981241, 0.00857054,
#        0.06215891, 0.01034467, 0.00706104, 0.03849705, 0.00446818,
#        0.00164152, 0.06161159, 0.04948809, 0.09585428, 0.01212221,
#        0.00488271, 0.013445  , 0.00191369, 0.01677086, 0.08913169,
#        0.00019097, 0.01421393, 0.02536412, 0.01047738, 0.0670003 ]), 'param_warm_start': masked_array(data=[True, True, False, True, True, True, False, False,
#                    True, True, True, True, True, False, False, True,
#                    False, True, False, True, True, True, True, False,
#                    False],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[118, 64, 118, 64, 445, 336, 391, 445, 227, 118, 64,
#                    391, 282, 500, 500, 173, 64, 10, 500, 445, 10, 64, 118,
#                    336, 445],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_min_samples_leaf': masked_array(data=[4, 4, 4, 1, 4, 2, 1, 4, 1, 1, 2, 4, 2, 2, 4, 1, 2, 1,
#                    1, 4, 2, 4, 2, 2, 4],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_max_features': masked_array(data=[1.0, 1.0, 'sqrt', 'log2', 1.0, 'sqrt', 1.0, 1.0,
#                    'sqrt', 'log2', 'sqrt', 'log2', 1.0, 'log2', 'sqrt',
#                    'log2', 1.0, 'log2', 'log2', 'log2', 'log2', 1.0,
#                    'log2', 1.0, 'sqrt'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_bootstrap': masked_array(data=[False, True, False, False, True, False, True, True,
#                    False, True, True, False, False, False, True, True,
#                    False, False, True, False, True, False, False, True,
#                    False],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'params': [{'warm_start': True, 'n_estimators': 118, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': False}, {'warm_start': True, 'n_estimators': 64, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': True}, {'warm_start': False, 'n_estimators': 118, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False}, {'warm_start': True, 'n_estimators': 64, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': True, 'n_estimators': 445, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': True}, {'warm_start': True, 'n_estimators': 336, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False}, {'warm_start': False, 'n_estimators': 391, 'min_samples_leaf': 1, 'max_features': 1.0, 'bootstrap': True}, {'warm_start': False, 'n_estimators': 445, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': True}, {'warm_start': True, 'n_estimators': 227, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}, {'warm_start': True, 'n_estimators': 118, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}, {'warm_start': True, 'n_estimators': 64, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True}, {'warm_start': True, 'n_estimators': 391, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': True, 'n_estimators': 282, 'min_samples_leaf': 2, 'max_features': 1.0, 'bootstrap': False}, {'warm_start': False, 'n_estimators': 500, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': False, 'n_estimators': 500, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': True}, {'warm_start': True, 'n_estimators': 173, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}, {'warm_start': False, 'n_estimators': 64, 'min_samples_leaf': 2, 'max_features': 1.0, 'bootstrap': False}, {'warm_start': True, 'n_estimators': 10, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': False, 'n_estimators': 500, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}, {'warm_start': True, 'n_estimators': 445, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': True, 'n_estimators': 10, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': True