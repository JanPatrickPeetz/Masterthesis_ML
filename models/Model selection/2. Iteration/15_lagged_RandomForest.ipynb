# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import ParameterGrid

# %%
# Set parameters for linear regression

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 500, num = 10)]
# Number of features to consider at every split
max_features = [1.0, 'sqrt', 'log2']
# Maximum number of levels in tree
#max_depth = [int(x) for x in np.linspace(10, 110, num = 5)]
#max_depth.append(None)
# Minimum number of samples required to split a node
#min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

warm_start = [True, False]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               #'max_depth': max_depth,
               #'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap,
               'warm_start': warm_start}

grid = ParameterGrid(random_grid)
cnt = 0
for p in grid:
    cnt = cnt+1

print('Total Possible Models',cnt)
# Out:
# Total Possible Models 360

# %%
#Define MASE Metric
def mean_absolute_scaled_error(y_true, y_pred):
    mase=0
    # Define numerator as the forecast error
    numerator = (np.abs(y_true - y_pred))

    # Define denominator as the mean absolute error of the in-sample one-step naive forecast
    y_true_ohne_1 = y_true[1:].reset_index(drop=True)
    y_true_ohne_ende = y_true[:-1].reset_index(drop=True)
    denominator = np.mean(np.abs(y_true_ohne_1 - y_true_ohne_ende))

    mase = np.mean(np.abs(numerator / denominator))

    return mase

scorer_mase= make_scorer(mean_absolute_scaled_error, greater_is_better=False)

# %%
# Load the data
data = pd.read_parquet('/Users/paddy/Documents/GitHub/Masterthesis_ML/data/03_15min_dataset.parquet')

# Convert the date column to datetime
data['date'] = pd.to_datetime(data['date']) #,format='%d/%m/%y %H:%M:%S').dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
#Feature engineering
# Create a new column for the time
data['time'] = [x for x in range(0, len(data))]

# Create the lagged features
lags = 96 + 1 # 24 hours lag + 1

# Create the lagged features
for i in range(1, lags):
    data['lag' + str(i)] = data['count'].shift(i)

# Drop the first three rows
data = data.dropna().reset_index(drop=True)

# Define the feature columns and the target column
feature_cols = [ f'lag{i}' for i in range(1, lags)]
target_col = 'y'

# Drop nan values
data = data.dropna()

# Rename column count to y
data = data.rename(columns={'count': 'y'})

# %%
# Set y to the last column
cols = list(data.columns.values) #Make a list of all of the columns in the df
cols.pop(cols.index('y')) #Remove y from list
data = data[cols+['y']] #Create new dataframe with columns in the order you want

# drop the date column
train_data = np.delete(data, 0, 1) 

# Split the data into X and y
X_train, y_train = train_data[:, :-1], train_data[:, -1]

# %%
#vgl: https://lightrun.com/answers/scikit-learn-scikit-learn-grid_search-feeding-parameters-to-scorer-functions

# X and y to pandas dataframe
X_train = pd.DataFrame(X_train)
y_train = pd.Series(y_train)

# %%
# Set Cross Validation to 5 iterations
tscv = TimeSeriesSplit(n_splits=5)

# %%
# Instantiate model
model = RandomForestRegressor()

search = RandomizedSearchCV(estimator = model, 
                            param_distributions = random_grid, 
                            n_iter = 25, 
                            cv = tscv,
                            refit=True, 
                            verbose=3, 
                            random_state=42, 
                            n_jobs = -1, 
                            scoring=scorer_mase, #make_scorer(scorer_mase, greater_is_better=True), #'neg_root_mean_squared_error', #
                            error_score=np.nan)

# %%
# Fit the random search model
search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.825 total time=  10.3s
# [CV 2/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.864 total time=  23.3s
# [CV 1/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=118, warm_start=True;, score=-1.098 total time=  29.9s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=118, warm_start=False;, score=-0.840 total time=   2.8s
# [CV 3/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.859 total time=  36.1s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=118, warm_start=False;, score=-0.857 total time=   6.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=118, warm_start=False;, score=-0.864 total time=   9.9s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=118, warm_start=False;, score=-0.866 total time=  13.7s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=64, warm_start=True;, score=-0.864 total time=   1.6s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=64, warm_start=True;, score=-0.893 total time=   3.2s
# [CV 4/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.855 total time=  49.2s
# [CV 2/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=118, warm_start=True;, score=-1.163 total time= 1.1min
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=64, warm_start=True;, score=-0.892 total time=   5.1s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=118, warm_start=False;, score=-0.835 total time=  18.0s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=64, warm_start=True;, score=-0.904 total time=   7.1s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=64, warm_start=True;, score=-0.862 total time=   9.5s
# [CV 5/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.833 total time= 1.1min
# [CV 3/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=118, warm_start=True;, score=-1.105 total time= 1.8min
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=2, n_estimators=336, warm_start=True;, score=-0.837 total time=  11.5s
# [CV 1/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.821 total time= 1.2min
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=2, n_estimators=336, warm_start=True;, score=-0.863 total time=  23.9s
# [CV 4/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=118, warm_start=True;, score=-1.121 total time= 2.6min
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=2, n_estimators=336, warm_start=True;, score=-0.872 total time=  37.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=2, n_estimators=336, warm_start=True;, score=-0.873 total time=  50.8s
# /Users/paddy/Library/Python/3.9/lib/python/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV 5/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=118, warm_start=True;, score=-1.071 total time= 3.5min
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=2, n_estimators=336, warm_start=True;, score=-0.838 total time= 1.1min
# [CV 2/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.858 total time= 2.8min
# [CV 1/5] END bootstrap=True, max_features=1.0, min_samples_leaf=1, n_estimators=391, warm_start=False;, score=-0.837 total time= 1.4min
# [CV 1/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.821 total time= 1.3min
# [CV 3/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.860 total time= 4.6min
# [CV 2/5] END bootstrap=True, max_features=1.0, min_samples_leaf=1, n_estimators=391, warm_start=False;, score=-0.938 total time= 3.2min
# [CV 4/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.851 total time= 6.4min
# [CV 2/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.859 total time= 2.9min
# [CV 3/5] END bootstrap=True, max_features=1.0, min_samples_leaf=1, n_estimators=391, warm_start=False;, score=-0.905 total time= 5.0min
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=1, n_estimators=227, warm_start=True;, score=-0.848 total time=   9.1s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=1, n_estimators=227, warm_start=True;, score=-0.877 total time=  19.3s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=1, n_estimators=227, warm_start=True;, score=-0.885 total time=  30.1s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=1, n_estimators=227, warm_start=True;, score=-0.885 total time=  40.6s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=118, warm_start=True;, score=-0.863 total time=   2.7s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=118, warm_start=True;, score=-0.892 total time=   5.1s
# [CV 5/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.827 total time= 8.3min
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=118, warm_start=True;, score=-0.899 total time=   7.7s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=118, warm_start=True;, score=-0.903 total time=  10.5s
# [CV 1/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=2, n_estimators=64, warm_start=True;, score=-0.852 total time=   1.5s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=1, n_estimators=227, warm_start=True;, score=-0.845 total time=  54.9s
# [CV 2/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=2, n_estimators=64, warm_start=True;, score=-0.874 total time=   3.4s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=118, warm_start=True;, score=-0.860 total time=  13.5s
# [CV 3/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=2, n_estimators=64, warm_start=True;, score=-0.877 total time=   5.3s
# [CV 4/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=2, n_estimators=64, warm_start=True;, score=-0.888 total time=   7.2s
# [CV 5/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=2, n_estimators=64, warm_start=True;, score=-0.846 total time=   9.0s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=391, warm_start=True;, score=-0.847 total time=   8.0s
# [CV 3/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.858 total time= 4.7min
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=391, warm_start=True;, score=-0.865 total time=  17.7s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=391, warm_start=True;, score=-0.873 total time=  27.6s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=391, warm_start=True;, score=-0.880 total time=  39.2s
# [CV 4/5] END bootstrap=True, max_features=1.0, min_samples_leaf=1, n_estimators=391, warm_start=False;, score=-0.869 total time= 7.3min
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=391, warm_start=True;, score=-0.841 total time=  49.6s
# [CV 1/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=282, warm_start=True;, score=-1.187 total time= 1.6min
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=500, warm_start=False;, score=-0.851 total time=  12.6s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=500, warm_start=False;, score=-0.869 total time=  25.7s
# [CV 4/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.852 total time= 6.7min
# [CV 5/5] END bootstrap=True, max_features=1.0, min_samples_leaf=1, n_estimators=391, warm_start=False;, score=-0.853 total time= 9.4min
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=500, warm_start=False;, score=-0.879 total time=  39.5s
# [CV 1/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=4, n_estimators=500, warm_start=False;, score=-0.843 total time=   9.3s
# [CV 2/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=4, n_estimators=500, warm_start=False;, score=-0.857 total time=  20.4s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=500, warm_start=False;, score=-0.885 total time=  56.1s
# [CV 2/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=282, warm_start=True;, score=-1.182 total time= 3.5min
# [CV 3/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=4, n_estimators=500, warm_start=False;, score=-0.868 total time=  32.7s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=500, warm_start=False;, score=-0.844 total time= 1.2min
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=173, warm_start=True;, score=-0.856 total time=   3.5s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=173, warm_start=True;, score=-0.887 total time=   7.6s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=173, warm_start=True;, score=-0.890 total time=  11.6s
# [CV 4/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=4, n_estimators=500, warm_start=False;, score=-0.873 total time=  46.0s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=173, warm_start=True;, score=-0.900 total time=  16.5s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=173, warm_start=True;, score=-0.858 total time=  20.9s
# [CV 5/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=4, n_estimators=500, warm_start=False;, score=-0.838 total time= 1.0min
# [CV 1/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=64, warm_start=False;, score=-1.189 total time=  24.4s
# [CV 2/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=64, warm_start=False;, score=-1.184 total time=  50.1s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=10, warm_start=True;, score=-0.901 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=10, warm_start=True;, score=-0.921 total time=   0.8s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=10, warm_start=True;, score=-0.928 total time=   1.3s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=10, warm_start=True;, score=-0.944 total time=   1.5s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=10, warm_start=True;, score=-0.888 total time=   1.8s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=500, warm_start=False;, score=-0.858 total time=  10.1s
# [CV 5/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.828 total time= 8.9min
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=500, warm_start=False;, score=-0.885 total time=  19.4s
# [CV 3/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=64, warm_start=False;, score=-1.160 total time= 1.3min
# [CV 3/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=282, warm_start=True;, score=-1.160 total time= 5.7min
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.850 total time=   9.6s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=500, warm_start=False;, score=-0.889 total time=  30.6s
# [CV 4/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=64, warm_start=False;, score=-1.178 total time= 1.9min
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=500, warm_start=False;, score=-0.901 total time=  41.4s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.864 total time=  19.7s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_leaf=2, n_estimators=10, warm_start=True;, score=-0.892 total time=   0.2s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_leaf=2, n_estimators=10, warm_start=True;, score=-0.897 total time=   0.4s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_leaf=2, n_estimators=10, warm_start=True;, score=-0.939 total time=   0.6s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_leaf=2, n_estimators=10, warm_start=True;, score=-0.934 total time=   0.8s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_leaf=2, n_estimators=10, warm_start=True;, score=-0.881 total time=   1.1s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=500, warm_start=False;, score=-0.856 total time=  52.1s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.872 total time=  29.8s
# [CV 1/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-1.099 total time=  18.4s
# [CV 5/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=64, warm_start=False;, score=-1.124 total time= 2.4min
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.880 total time=  40.8s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=118, warm_start=True;, score=-0.855 total time=   2.6s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=118, warm_start=True;, score=-0.871 total time=   5.6s
# [CV 2/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-1.163 total time=  38.5s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.843 total time=  52.0s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=118, warm_start=True;, score=-0.882 total time=   9.0s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=118, warm_start=True;, score=-0.885 total time=  12.1s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=118, warm_start=True;, score=-0.847 total time=  15.5s
# [CV 3/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-1.106 total time= 1.0min
# [CV 4/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=282, warm_start=True;, score=-1.178 total time= 8.0min
# [CV 4/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-1.121 total time= 1.4min
# [CV 1/5] END bootstrap=True, max_features=1.0, min_samples_leaf=2, n_estimators=336, warm_start=False;, score=-0.829 total time= 1.1min
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.839 total time=  11.8s
# [CV 5/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-1.071 total time= 1.9min
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.856 total time=  27.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.862 total time=  44.6s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.863 total time=  59.6s
# [CV 2/5] END bootstrap=True, max_features=1.0, min_samples_leaf=2, n_estimators=336, warm_start=False;, score=-0.889 total time= 2.5min
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.831 total time= 1.2min
# [CV 5/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=282, warm_start=True;, score=-1.123 total time= 9.9min
# [CV 3/5] END bootstrap=True, max_features=1.0, min_samples_leaf=2, n_estimators=336, warm_start=False;, score=-0.877 total time= 3.6min
# [CV 4/5] END bootstrap=True, max_features=1.0, min_samples_leaf=2, n_estimators=336, warm_start=False;, score=-0.860 total time= 4.4min
# [CV 5/5] END bootstrap=True, max_features=1.0, min_samples_leaf=2, n_estimators=336, warm_start=False;, score=-0.837 total time= 5.2min
# RandomizedSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#                    estimator=RandomForestRegressor(), n_iter=25, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_features': [1.0, 'sqrt', 'log2'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'n_estimators': [10, 64, 118, 173, 227,
#                                                          282, 336, 391, 445,
#                                                          500],
#                                         'warm_start': [True, False]},
#                    random_state=42,
#                    scoring=make_scorer(mean_absolute_scaled_error, greater_is_better=False),
#                    verbose=3)

# %%
print('Best Score: %s' % search.best_score_)
print('Best Hyperparameters: %s' % search.best_params_)
print('Best Model: %s' % search.best_estimator_)
print('Best Index: %s' % search.best_index_)
print('CV Results: %s' % search.cv_results_)
print('Refit Time: %s' % search.refit_time_)
print('Scorer: %s' % search.scorer_)
# Out:
# Best Score: -0.8434750925022113
# Best Hyperparameters: {'warm_start': False, 'n_estimators': 445, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': True}
# Best Model: RandomForestRegressor(min_samples_leaf=4, n_estimators=445)
# Best Index: 7
# CV Results: {'mean_fit_time': array([113.89629226,  36.69346862,   9.97236595,   5.17217517,
#        279.46202097,  37.48388081, 314.39905486, 292.32783685,
#         30.344732  ,   7.68599043,   5.17605033,  27.87877955,
#        344.39032097,  40.53710785,  33.3525723 ,  11.64384437,
#         81.46242566,   1.10601635,  29.88555803,  29.79894195,
#          0.56844068,  63.8496408 ,   8.78914394, 200.10257354,
#         42.83536539]), 'std_fit_time': array([ 64.83875854,  19.13630681,   5.34671501,   2.76342505,
#        150.04697283,  19.33494981, 170.52868414, 161.8052752 ,
#         15.88733188,   3.78948127,   2.65609427,  14.69232698,
#        180.18811205,  21.22387508,  18.28424308,   6.13017196,
#         41.82404596,   0.52887071,  14.83313292,  14.89381818,
#          0.29875533,  34.28927699,   4.54214752,  87.26149189,
#         22.01751398]), 'mean_score_time': array([0.14234877, 0.07205496, 0.13734083, 0.13096766, 0.50695629,
#        0.52794418, 0.6065042 , 0.55035472, 0.45364771, 0.20858541,
#        0.1007    , 0.5639585 , 0.41314721, 0.85634675, 0.63353901,
#        0.34954023, 0.14195871, 0.04047041, 0.85485339, 0.56664534,
#        0.03219161, 0.09311934, 0.18193703, 0.33428502, 0.52906885]), 'std_score_time': array([0.04558087, 0.01854135, 0.02213873, 0.03578083, 0.10160969,
#        0.08394966, 0.15536978, 0.08326185, 0.11511691, 0.04038839,
#        0.00807149, 0.10770101, 0.06546368, 0.21960227, 0.13563016,
#        0.10345229, 0.03064824, 0.00432754, 0.17913279, 0.08265777,
#        0.0059053 , 0.00654678, 0.02673463, 0.06101637, 0.06927343]), 'param_warm_start': masked_array(data=[True, True, False, True, True, True, False, False,
#                    True, True, True, True, True, False, False, True,
#                    False, True, False, True, True, True, True, False,
#                    False],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[118, 64, 118, 64, 445, 336, 391, 445, 227, 118, 64,
#                    391, 282, 500, 500, 173, 64, 10, 500, 445, 10, 64, 118,
#                    336, 445],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_min_samples_leaf': masked_array(data=[4, 4, 4, 1, 4, 2, 1, 4, 1, 1, 2, 4, 2, 2, 4, 1, 2, 1,
#                    1, 4, 2, 4, 2, 2, 4],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_max_features': masked_array(data=[1.0, 1.0, 'sqrt', 'log2', 1.0, 'sqrt', 1.0, 1.0,
#                    'sqrt', 'log2', 'sqrt', 'log2', 1.0, 'log2', 'sqrt',
#                    'log2', 1.0, 'log2', 'log2', 'log2', 'log2', 1.0,
#                    'log2', 1.0, 'sqrt'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_bootstrap': masked_array(data=[False, True, False, False, True, False, True, True,
#                    False, True, True, False, False, False, True, True,
#                    False, False, True, False, True, False, False, True,
#                    False],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'params': [{'warm_start': True, 'n_estimators': 118, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': False}, {'warm_start': True, 'n_estimators': 64, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': True}, {'warm_start': False, 'n_estimators': 118, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False}, {'warm_start': True, 'n_estimators': 64, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': True, 'n_estimators': 445, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': True}, {'warm_start': True, 'n_estimators': 336, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False}, {'warm_start': False, 'n_estimators': 391, 'min_samples_leaf': 1, 'max_features': 1.0, 'bootstrap': True}, {'warm_start': False, 'n_estimators': 445, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': True}, {'warm_start': True, 'n_estimators': 227, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}, {'warm_start': True, 'n_estimators': 118, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}, {'warm_start': True, 'n_estimators': 64, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True}, {'warm_start': True, 'n_estimators': 391, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': True, 'n_estimators': 282, 'min_samples_leaf': 2, 'max_features': 1.0, 'bootstrap': False}, {'warm_start': False, 'n_estimators': 500, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': False, 'n_estimators': 500, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': True}, {'warm_start': True, 'n_estimators': 173, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}, {'warm_start': False, 'n_estimators': 64, 'min_samples_leaf': 2, 'max_features': 1.0, 'bootstrap': False}, {'warm_start': True, 'n_estimators': 10, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': False, 'n_estimators': 500, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}, {'warm_start': True, 'n_estimators': 445, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': True, 'n_estimators': 10, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': True}, {'warm_start': True, 'n_estimators': 64, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': False}, {'warm_start': True, 'n_estimators': 118, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': False, 'n_estimators': 336, 'min_samples_leaf': 2, 'max_features': 1.0, 'bootstrap': True}, {'warm_start': False, 'n_estimators': 445, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False