# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer
from sklearn.linear_model import Ridge

# %%
# Set parameters for linear regression

# ridge parameters for random search
fit_intercept = [True, False]
copy_X = [True, False]
alpha = [0.1, 0.5, 1, 2, 5, 10, 20, 50, 100]
tol = [0.0001, 0.001, 0.01, 0.1, 1, 10, 100]
solver = ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']

# Create the random grid
random_grid = {'fit_intercept': fit_intercept,
                'copy_X': copy_X,
                'alpha': alpha,
                'tol': tol,
                'solver': solver}

# %%
#Define MASE Metric
def mean_absolute_scaled_error(y_true, y_pred):
    mase=0
    # Define numerator as the forecast error
    numerator = (np.abs(y_true - y_pred))

    # Define denominator as the mean absolute error of the in-sample one-step naive forecast
    y_true_ohne_1 = y_true[1:].reset_index(drop=True)
    y_true_ohne_ende = y_true[:-1].reset_index(drop=True)
    denominator = np.mean(np.abs(y_true_ohne_1 - y_true_ohne_ende))

    mase = np.mean(np.abs(numerator / denominator))

    return mase

scorer_mase= make_scorer(mean_absolute_scaled_error, greater_is_better=False)

# %%
# Load the data
data = pd.read_parquet('/Users/paddy/Documents/GitHub/Masterthesis_ML/data/03_30min_dataset.parquet')

# Convert the date column to datetime
data['date'] = pd.to_datetime(data['date']) #,format='%d/%m/%y %H:%M:%S').dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
#Feature engineering
# Create a new column for the time
data['time'] = [x for x in range(0, len(data))]

# Create the lagged features
lags = 48 + 1

# Create the lagged features
for i in range(1, lags):
    data['lag' + str(i)] = data['count'].shift(i)

# Drop the first three rows
data = data.dropna().reset_index(drop=True)

# Define the feature columns and the target column
feature_cols = [ f'lag{i}' for i in range(1, lags)]
target_col = 'y'

# Drop nan values
data = data.dropna()

# Rename column count to y
data = data.rename(columns={'count': 'y'})

# %%
# Set y to the last column
cols = list(data.columns.values) #Make a list of all of the columns in the df
cols.pop(cols.index('y')) #Remove y from list
data = data[cols+['y']] #Create new dataframe with columns in the order you want

# drop the date column
train_data = np.delete(data, 0, 1) 

# Split the data into X and y
X_train, y_train = train_data[:, :-1], train_data[:, -1]

# %%
#vgl: https://lightrun.com/answers/scikit-learn-scikit-learn-grid_search-feeding-parameters-to-scorer-functions

# X and y to pandas dataframe
X_train = pd.DataFrame(X_train)
y_train = pd.Series(y_train)

# %%
# Set Cross Validation to 5 iterations
tscv = TimeSeriesSplit(n_splits=5)

# %%
# Instantiate model
model = Ridge()

search = RandomizedSearchCV(estimator = model, 
                               param_distributions = random_grid, 
                               n_iter = 25, 
                               cv = tscv,
                               refit=True, 
                               verbose=3, 
                               random_state=42, 
                               n_jobs = -1, 
                               scoring=scorer_mase, #make_scorer(scorer_mase, greater_is_better=True), #'neg_root_mean_squared_error', #
                               error_score=np.nan)

# %%
# Fit the random search model
search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=0.001;, score=-0.789 total time=   0.0s
# [CV 2/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=0.001;, score=-0.848 total time=   0.0s
# [CV 3/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=0.001;, score=-0.817 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=cholesky, tol=0.01;, score=-0.789 total time=   0.0s
# [CV 4/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=0.001;, score=-0.789 total time=   0.1s
# [CV 5/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=0.001;, score=-0.770 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=cholesky, tol=0.01;, score=-0.790 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=cholesky, tol=0.01;, score=-0.770 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=cholesky, tol=0.01;, score=-0.848 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=cholesky, tol=0.01;, score=-0.817 total time=   0.0s
# [CV 1/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=0.1;, score=-0.796 total time=   0.0s
# [CV 2/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=0.1;, score=-0.846 total time=   0.0s
# [CV 3/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=0.1;, score=-0.822 total time=   0.0s
# [CV 4/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=0.1;, score=-0.795 total time=   0.0s
# [CV 1/5] END alpha=50, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.609 total time=   0.0s
# [CV 5/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=0.1;, score=-0.775 total time=   0.1s
# [CV 2/5] END alpha=50, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.267 total time=   0.0s
# [CV 3/5] END alpha=50, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.473 total time=   0.0s
# [CV 4/5] END alpha=50, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.423 total time=   0.0s
# [CV 5/5] END alpha=50, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.286 total time=   0.0s
# [CV 1/5] END alpha=20, copy_X=False, fit_intercept=True, solver=lsqr, tol=0.001;, score=-0.789 total time=   0.0s
# [CV 2/5] END alpha=20, copy_X=False, fit_intercept=True, solver=lsqr, tol=0.001;, score=-0.846 total time=   0.0s
# [CV 3/5] END alpha=20, copy_X=False, fit_intercept=True, solver=lsqr, tol=0.001;, score=-0.864 total time=   0.0s
# [CV 4/5] END alpha=20, copy_X=False, fit_intercept=True, solver=lsqr, tol=0.001;, score=-0.846 total time=   0.0s
# [CV 5/5] END alpha=20, copy_X=False, fit_intercept=True, solver=lsqr, tol=0.001;, score=-0.821 total time=   0.0s
# [CV 1/5] END alpha=2, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.01;, score=-0.931 total time=   0.0s
# [CV 2/5] END alpha=2, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.01;, score=-2.400 total time=   0.0s
# [CV 3/5] END alpha=2, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.01;, score=-2.038 total time=   0.0s
# [CV 4/5] END alpha=2, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.01;, score=-1.880 total time=   0.0s
# [CV 5/5] END alpha=2, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.01;, score=-1.623 total time=   0.0s
# [CV 1/5] END alpha=100, copy_X=False, fit_intercept=True, solver=sag, tol=0.0001;, score=-0.789 total time=   0.1s
# [CV 1/5] END alpha=1, copy_X=False, fit_intercept=True, solver=sag, tol=1;, score=-2.253 total time=   0.0s
# [CV 2/5] END alpha=1, copy_X=False, fit_intercept=True, solver=sag, tol=1;, score=-1.734 total time=   0.0s
# [CV 3/5] END alpha=1, copy_X=False, fit_intercept=True, solver=sag, tol=1;, score=-5.307 total time=   0.0s
# [CV 4/5] END alpha=1, copy_X=False, fit_intercept=True, solver=sag, tol=1;, score=-1.328 total time=   0.0s
# [CV 5/5] END alpha=1, copy_X=False, fit_intercept=True, solver=sag, tol=1;, score=-1.369 total time=   0.0s
# [CV 1/5] END alpha=10, copy_X=False, fit_intercept=False, solver=saga, tol=10;, score=-3.042 total time=   0.0s
# [CV 2/5] END alpha=10, copy_X=False, fit_intercept=False, solver=saga, tol=10;, score=-2.208 total time=   0.0s
# [CV 3/5] END alpha=10, copy_X=False, fit_intercept=False, solver=saga, tol=10;, score=-2.740 total time=   0.0s
# [CV 2/5] END alpha=100, copy_X=False, fit_intercept=True, solver=sag, tol=0.0001;, score=-0.848 total time=   0.6s
# [CV 4/5] END alpha=10, copy_X=False, fit_intercept=False, solver=saga, tol=10;, score=-1.535 total time=   0.0s
# [CV 5/5] END alpha=10, copy_X=False, fit_intercept=False, solver=saga, tol=10;, score=-1.528 total time=   0.0s
# [CV 1/5] END alpha=1, copy_X=True, fit_intercept=False, solver=svd, tol=0.01;, score=-0.796 total time=   0.0s
# [CV 2/5] END alpha=1, copy_X=True, fit_intercept=False, solver=svd, tol=0.01;, score=-0.846 total time=   0.0s
# [CV 3/5] END alpha=1, copy_X=True, fit_intercept=False, solver=svd, tol=0.01;, score=-0.822 total time=   0.0s
# [CV 4/5] END alpha=1, copy_X=True, fit_intercept=False, solver=svd, tol=0.01;, score=-0.795 total time=   0.0s
# [CV 5/5] END alpha=1, copy_X=True, fit_intercept=False, solver=svd, tol=0.01;, score=-0.775 total time=   0.1s
# [CV 1/5] END alpha=100, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=1;, score=-2.039 total time=   0.0s
# [CV 2/5] END alpha=100, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=1;, score=-2.400 total time=   0.0s
# [CV 3/5] END alpha=100, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=1;, score=-2.025 total time=   0.0s
# [CV 4/5] END alpha=100, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=1;, score=-1.963 total time=   0.0s
# [CV 5/5] END alpha=100, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=1;, score=-1.623 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.831 total time=   0.0s
# [CV 3/5] END alpha=100, copy_X=False, fit_intercept=True, solver=sag, tol=0.0001;, score=-0.817 total time=   1.2s
# [CV 2/5] END alpha=0.5, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.618 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.387 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.330 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=False, fit_intercept=True, solver=saga, tol=100;, score=-1.339 total time=   0.0s
# [CV 1/5] END alpha=5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.001;, score=-0.789 total time=   0.0s
# [CV 2/5] END alpha=5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.001;, score=-0.846 total time=   0.0s
# [CV 3/5] END alpha=5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.001;, score=-0.864 total time=   0.0s
# [CV 4/5] END alpha=5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.001;, score=-0.846 total time=   0.0s
# [CV 5/5] END alpha=5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.001;, score=-0.821 total time=   0.0s
# [CV 1/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sag, tol=10;, score=-4.534 total time=   0.0s
# [CV 2/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sag, tol=10;, score=-1.515 total time=   0.0s
# [CV 3/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sag, tol=10;, score=-2.438 total time=   0.0s
# [CV 4/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sag, tol=10;, score=-5.209 total time=   0.0s
# [CV 5/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sag, tol=10;, score=-3.773 total time=   0.0s
# [CV 1/5] END alpha=20, copy_X=True, fit_intercept=False, solver=saga, tol=10;, score=-1.735 total time=   0.0s
# [CV 2/5] END alpha=20, copy_X=True, fit_intercept=False, solver=saga, tol=10;, score=-1.922 total time=   0.0s
# [CV 3/5] END alpha=20, copy_X=True, fit_intercept=False, solver=saga, tol=10;, score=-1.549 total time=   0.0s
# [CV 4/5] END alpha=20, copy_X=True, fit_intercept=False, solver=saga, tol=10;, score=-2.140 total time=   0.0s
# [CV 5/5] END alpha=20, copy_X=True, fit_intercept=False, solver=saga, tol=10;, score=-1.354 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=saga, tol=0.001;, score=-0.788 total time=   0.2s
# [CV 1/5] END alpha=1, copy_X=False, fit_intercept=False, solver=lsqr, tol=0.001;, score=-0.804 total time=   0.0s
# [CV 2/5] END alpha=1, copy_X=False, fit_intercept=False, solver=lsqr, tol=0.001;, score=-0.854 total time=   0.0s
# [CV 3/5] END alpha=1, copy_X=False, fit_intercept=False, solver=lsqr, tol=0.001;, score=-0.956 total time=   0.0s
# [CV 4/5] END alpha=1, copy_X=False, fit_intercept=False, solver=lsqr, tol=0.001;, score=-0.921 total time=   0.0s
# [CV 5/5] END alpha=1, copy_X=False, fit_intercept=False, solver=lsqr, tol=0.001;, score=-0.908 total time=   0.0s
# [CV 4/5] END alpha=100, copy_X=False, fit_intercept=True, solver=sag, tol=0.0001;, score=-0.790 total time=   2.5s
# [CV 1/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=1;, score=-0.796 total time=   0.0s
# [CV 2/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=1;, score=-0.846 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=saga, tol=0.001;, score=-0.845 total time=   0.6s
# [CV 3/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=1;, score=-0.822 total time=   0.1s
# [CV 4/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=1;, score=-0.795 total time=   0.1s
# [CV 5/5] END alpha=100, copy_X=False, fit_intercept=False, solver=svd, tol=1;, score=-0.775 total time=   0.1s
# [CV 1/5] END alpha=0.5, copy_X=True, fit_intercept=False, solver=auto, tol=100;, score=-0.796 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=True, fit_intercept=False, solver=auto, tol=100;, score=-0.846 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=True, fit_intercept=False, solver=auto, tol=100;, score=-0.822 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=True, fit_intercept=False, solver=auto, tol=100;, score=-0.795 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=True, fit_intercept=False, solver=auto, tol=100;, score=-0.775 total time=   0.0s
# [CV 1/5] END alpha=0.1, copy_X=True, fit_intercept=False, solver=cholesky, tol=0.01;, score=-0.796 total time=   0.0s
# [CV 2/5] END alpha=0.1, copy_X=True, fit_intercept=False, solver=cholesky, tol=0.01;, score=-0.846 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=saga, tol=0.001;, score=-0.822 total time=   1.2s
# [CV 3/5] END alpha=0.1, copy_X=True, fit_intercept=False, solver=cholesky, tol=0.01;, score=-0.822 total time=   0.0s
# [CV 4/5] END alpha=0.1, copy_X=True, fit_intercept=False, solver=cholesky, tol=0.01;, score=-0.795 total time=   0.0s
# [CV 5/5] END alpha=0.1, copy_X=True, fit_intercept=False, solver=cholesky, tol=0.01;, score=-0.775 total time=   0.0s
# [CV 1/5] END alpha=20, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.001;, score=-0.822 total time=   0.0s
# [CV 2/5] END alpha=20, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.001;, score=-0.905 total time=   0.0s
# [CV 3/5] END alpha=20, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.001;, score=-0.956 total time=   0.0s
# [CV 4/5] END alpha=20, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.001;, score=-0.980 total time=   0.0s
# [CV 5/5] END alpha=20, copy_X=False, fit_intercept=False, solver=sparse_cg, tol=0.001;, score=-0.970 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.1;, score=-1.486 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.1;, score=-1.558 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.1;, score=-1.474 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=saga, tol=0.001;, score=-0.802 total time=   1.8s
# [CV 4/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.1;, score=-1.449 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=lsqr, tol=0.1;, score=-0.938 total time=   0.0s
# [CV 5/5] END alpha=100, copy_X=False, fit_intercept=True, solver=sag, tol=0.0001;, score=-0.771 total time=   4.0s
# [CV 1/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=0.0001;, score=-0.794 total time=   0.0s
# [CV 2/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=0.0001;, score=-0.844 total time=   0.0s
# [CV 3/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=0.0001;, score=-0.834 total time=   0.0s
# [CV 4/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=0.0001;, score=-0.813 total time=   0.0s
# [CV 5/5] END alpha=5, copy_X=True, fit_intercept=False, solver=sparse_cg, tol=0.0001;, score=-0.797 total time=   0.0s
# [CV 1/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=svd, tol=0.0001;, score=-0.790 total time=   0.0s
# [CV 2/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=svd, tol=0.0001;, score=-0.848 total time=   0.0s
# [CV 3/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=svd, tol=0.0001;, score=-0.817 total time=   0.0s
# [CV 4/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=svd, tol=0.0001;, score=-0.789 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=svd, tol=0.0001;, score=-0.770 total time=   0.1s
# [CV 1/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=100;, score=-1.463 total time=   0.0s
# [CV 2/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=100;, score=-1.543 total time=   0.0s
# [CV 3/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=100;, score=-1.478 total time=   0.0s
# [CV 4/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=100;, score=-1.452 total time=   0.0s
# [CV 5/5] END alpha=10, copy_X=False, fit_intercept=True, solver=sparse_cg, tol=100;, score=-1.358 total time=   0.0s
# [CV 5/5] END alpha=0.5, copy_X=True, fit_intercept=True, solver=saga, tol=0.001;, score=-0.788 total time=   2.5s
# RandomizedSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#                    estimator=Ridge(), n_iter=25, n_jobs=-1,
#                    param_distributions={'alpha': [0.1, 0.5, 1, 2, 5, 10, 20, 50,
#                                                   100],
#                                         'copy_X': [True, False],
#                                         'fit_intercept': [True, False],
#                                         'solver': ['auto', 'svd', 'cholesky',
#                                                    'lsqr', 'sparse_cg', 'sag',
#                                                    'saga'],
#                                         'tol': [0.0001, 0.001, 0.01, 0.1, 1, 10,
#                                                 100]},
#                    random_state=42,
#                    scoring=make_scorer(mean_absolute_scaled_error, greater_is_better=False),
#                    verbose=3)

# %%
print('Best Score: %s' % search.best_score_)
print('Best Hyperparameters: %s' % search.best_params_)
print('Best Model: %s' % search.best_estimator_)
print('Best Index: %s' % search.best_index_)
print('CV Results: %s' % search.cv_results_)
print('Refit Time: %s' % search.refit_time_)
print('Scorer: %s' % search.scorer_)
# Out:
# Best Score: -0.8027533326416207
# Best Hyperparameters: {'tol': 0.001, 'solver': 'sparse_cg', 'fit_intercept': True, 'copy_X': False, 'alpha': 10}
# Best Model: Ridge(alpha=10, copy_X=False, solver='sparse_cg', tol=0.001)
# Best Index: 0
# CV Results: {'mean_fit_time': array([0.0248322 , 0.02359118, 0.02833853, 0.01738276, 0.01345301,
#        0.01230283, 1.69453883, 0.01731658, 0.01696501, 0.03439512,
#        0.01414356, 0.01776657, 0.01409931, 0.02047524, 0.02042904,
#        1.24691095, 0.0158155 , 0.03828526, 0.02168384, 0.01857605,
#        0.01540279, 0.01458364, 0.01881762, 0.03176656, 0.0131156 ]), 'std_fit_time': array([0.01502874, 0.00994117, 0.01144636, 0.00704271, 0.00476681,
#        0.00450656, 1.38945856, 0.00879521, 0.00644429, 0.01699411,
#        0.00688164, 0.0067397 , 0.00570578, 0.01208006, 0.00846063,
#        0.83405512, 0.00683872, 0.01738689, 0.00843282, 0.00803891,
#        0.00551062, 0.00415824, 0.00777648, 0.01378564, 0.00459075]), 'mean_score_time': array([0.00774856, 0.00707445, 0.00535564, 0.00435219, 0.00431576,
#        0.00393085, 0.00444818, 0.00384173, 0.00423098, 0.00496626,
#        0.00479112, 0.00454607, 0.0054976 , 0.00614843, 0.00605326,
#        0.00554781, 0.00408492, 0.00507336, 0.00471439, 0.00436096,
#        0.00540624, 0.00558615, 0.00580831, 0.0051394 , 0.00513482]), 'std_score_time': array([0.00347331, 0.00169323, 0.0016224 , 0.00040461, 0.00048356,
#        0.00020942, 0.00041562, 0.00015069, 0.00057167, 0.00102081,
#        0.00176085, 0.00082381, 0.00214824, 0.00197584, 0.00209654,
#        0.0016252 , 0.0003594 , 0.00086293, 0.00072356, 0.00049623,
#        0.0015054 , 0.0019248 , 0.00136981, 0.00095951, 0.00082503]), 'param_tol': masked_array(data=[0.001, 0.01, 0.1, 100, 0.001, 0.01, 0.0001, 1, 10,
#                    0.01, 1, 100, 0.001, 10, 10, 0.001, 0.001, 1, 100,
#                    0.01, 0.001, 0.1, 0.0001, 0.0001, 100],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_solver': masked_array(data=['sparse_cg', 'cholesky', 'svd', 'saga', 'lsqr',
#                    'sparse_cg', 'sag', 'sag', 'saga', 'svd', 'sparse_cg',
#                    'saga', 'lsqr', 'sag', 'saga', 'saga', 'lsqr', 'svd',
#                    'auto', 'cholesky', 'sparse_cg', 'lsqr', 'sparse_cg',
#                    'svd', 'sparse_cg'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_fit_intercept': masked_array(data=[True, True, False, True, True, False, True, True,
#                    False, False, False, True, True, False, False, True,
#                    False, False, False, False, False, True, False, True,
#                    True],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_copy_X': masked_array(data=[False, True, False, False, False, False, False, False,
#                    False, True, True, False, True, True, True, True,
#                    False, False, True, True, False, True, True, True,
#                    False],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_alpha': masked_array(data=[10, 0.5, 100, 50, 20, 2, 100, 1, 10, 1, 100, 0.5, 5, 5,
#                    20, 0.5, 1, 100, 0.5, 0.1, 20, 0.5, 5, 0.5, 10],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'params': [{'tol': 0.001, 'solver': 'sparse_cg', 'fit_intercept': True, 'copy_X': False, 'alpha': 10}, {'tol': 0.01, 'solver': 'cholesky', 'fit_intercept': True, 'copy_X': True, 'alpha': 0.5}, {'tol': 0.1, 'solver': 'svd', 'fit_intercept': False, 'copy_X': False, 'alpha': 100}, {'tol': 100, 'solver': 'saga', 'fit_intercept': True, 'copy_X': False, 'alpha': 50}, {'tol': 0.001, 'solver': 'lsqr', 'fit_intercept': True, 'copy_X': False, 'alpha': 20}, {'tol': 0.01, 'solver': 'sparse_cg', 'fit_intercept': False, 'copy_X': False, 'alpha': 2}, {'tol': 0.0001, 'solver': 'sag', 'fit_intercept': True, 'copy_X': False, 'alpha': 100}, {'tol': 1, 'solver': 'sag', 'fit_intercept': True, 'copy_X': False, 'alpha': 1}, {'tol': 10, 'solver': 'saga', 'fit_intercept': False, 'copy_X': False, 'alpha': 10}, {'tol': 0.01, 'solver': 'svd', 'fit_intercept': False, 'copy_X': True, 'alpha': 1}, {'tol': 1, 'solver': 'sparse_cg', 'fit_intercept': False, 'copy_X': True, 'alpha': 100}, {'tol': 100, 'solver': 'saga', 'fit_intercept': True, 'copy_X': False, 'alpha': 0.5}, {'tol': 0.001, 'solver': 'lsqr', 'fit_intercept': True, 'copy_X': True, 'alpha': 5}, {'tol': 10, 'solver': 'sag', 'fit_intercept': False, 'copy_X': True, 'alpha': 5}, {'tol': 10, 'solver': 'saga', 'fit_intercept': False, 'copy_X': True, 'alpha': 20}, {'tol': 0.001, 'solver': 'saga', 'fit_intercept': True, 'copy_X': True, 'alpha': 0.5}, {'tol': 0.001, 'solver': 'lsqr', 'fit_intercept': False, 'copy_X': False, 'alpha': 1}, {'tol': 1, 'solver': 'svd', 'fit_intercept': False, 'copy_X': False, 'alpha': 100}, {'tol': 100, 'solver': 'auto', 'fit_intercept': False, 'copy_X': True, 'alpha': 0.5}, {'tol': 0.01, 'solver': 'cholesky', 'fit_intercept': False, 'copy_X': True, 'alpha': 0.1}, {'tol': 0.001, 'solver': 'sparse_cg', 'fit_intercept': False, 'copy_X': False, 'alpha': 20}, {'tol': 0.1, 'solver': 'lsqr', 'fit_intercept': True, 'copy_X': True, 'alpha': 0.5}, {'tol': 0.0001, 'solver': 'sparse_cg', 'fit_intercept': False, 'copy_X': True, 'alpha': 5}, {'tol': 0.0001, 'solver': 'svd', 'fit_intercept': True, 'copy_X': True, 'alpha': 0.5}, {'tol': 100, 'solver': 'sparse_cg', 'fit_intercept': True, 'copy_X': False, 'alpha': 10