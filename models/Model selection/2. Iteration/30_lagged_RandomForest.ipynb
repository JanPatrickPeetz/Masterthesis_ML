# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import ParameterGrid

# %%
# Set parameters for linear regression

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 500, num = 10)]
# Number of features to consider at every split
max_features = [1.0, 'sqrt', 'log2']
# Maximum number of levels in tree
#max_depth = [int(x) for x in np.linspace(10, 110, num = 5)]
#max_depth.append(None)
# Minimum number of samples required to split a node
#min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

warm_start = [True, False]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               #'max_depth': max_depth,
               #'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap,
               'warm_start': warm_start}

grid = ParameterGrid(random_grid)
cnt = 0
for p in grid:
    cnt = cnt+1

print('Total Possible Models',cnt)
# Out:
# Total Possible Models 360

# %%
#Define MASE Metric
def mean_absolute_scaled_error(y_true, y_pred):
    mase=0
    # Define numerator as the forecast error
    numerator = (np.abs(y_true - y_pred))

    # Define denominator as the mean absolute error of the in-sample one-step naive forecast
    y_true_ohne_1 = y_true[1:].reset_index(drop=True)
    y_true_ohne_ende = y_true[:-1].reset_index(drop=True)
    denominator = np.mean(np.abs(y_true_ohne_1 - y_true_ohne_ende))

    mase = np.mean(np.abs(numerator / denominator))

    return mase

scorer_mase= make_scorer(mean_absolute_scaled_error, greater_is_better=False)

# %%
# Load the data
data = pd.read_parquet('/Users/paddy/Documents/GitHub/Masterthesis_ML/data/03_30min_dataset.parquet')

# Convert the date column to datetime
data['date'] = pd.to_datetime(data['date']) #,format='%d/%m/%y %H:%M:%S').dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
#Feature engineering
# Create a new column for the time
data['time'] = [x for x in range(0, len(data))]

# Create the lagged features
lags = 48 + 1 # 24 hours lag + 1

# Create the lagged features
for i in range(1, lags):
    data['lag' + str(i)] = data['count'].shift(i)

# Drop the first three rows
data = data.dropna().reset_index(drop=True)

# Define the feature columns and the target column
feature_cols = [ f'lag{i}' for i in range(1, lags)]
target_col = 'y'

# Drop nan values
data = data.dropna()

# Rename column count to y
data = data.rename(columns={'count': 'y'})

# %%
# Set y to the last column
cols = list(data.columns.values) #Make a list of all of the columns in the df
cols.pop(cols.index('y')) #Remove y from list
data = data[cols+['y']] #Create new dataframe with columns in the order you want

# drop the date column
train_data = np.delete(data, 0, 1) 

# Split the data into X and y
X_train, y_train = train_data[:, :-1], train_data[:, -1]

# %%
#vgl: https://lightrun.com/answers/scikit-learn-scikit-learn-grid_search-feeding-parameters-to-scorer-functions

# X and y to pandas dataframe
X_train = pd.DataFrame(X_train)
y_train = pd.Series(y_train)

# %%
# Set Cross Validation to 5 iterations
tscv = TimeSeriesSplit(n_splits=5)

# %%
# Instantiate model
model = RandomForestRegressor()

search = RandomizedSearchCV(estimator = model, 
                            param_distributions = random_grid, 
                            n_iter = 25, 
                            cv = tscv,
                            refit=True, 
                            verbose=3, 
                            random_state=42, 
                            n_jobs = -1, 
                            scoring=scorer_mase, #make_scorer(scorer_mase, greater_is_better=True), #'neg_root_mean_squared_error', #
                            error_score=np.nan)

# %%
# Fit the random search model
search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.776 total time=   2.8s
# [CV 2/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.821 total time=   5.8s
# [CV 1/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=118, warm_start=True;, score=-1.004 total time=   7.8s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=118, warm_start=False;, score=-0.776 total time=   1.2s
# [CV 3/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.783 total time=   9.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=118, warm_start=False;, score=-0.813 total time=   2.8s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=118, warm_start=False;, score=-0.786 total time=   5.0s
# [CV 4/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.779 total time=  13.9s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=64, warm_start=True;, score=-0.803 total time=   0.7s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=118, warm_start=False;, score=-0.781 total time=   6.6s
# [CV 2/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=118, warm_start=True;, score=-1.082 total time=  18.6s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=64, warm_start=True;, score=-0.845 total time=   1.4s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=64, warm_start=True;, score=-0.812 total time=   2.0s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=64, warm_start=True;, score=-0.807 total time=   3.0s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=118, warm_start=False;, score=-0.735 total time=   7.6s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=64, warm_start=True;, score=-0.751 total time=   4.0s
# [CV 5/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.734 total time=  18.0s
# [CV 3/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=118, warm_start=True;, score=-1.004 total time=  30.0s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=2, n_estimators=336, warm_start=True;, score=-0.783 total time=   4.4s
# [CV 1/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.772 total time=  18.2s
# [CV 4/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=118, warm_start=True;, score=-0.988 total time=  40.4s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=2, n_estimators=336, warm_start=True;, score=-0.819 total time=   9.1s
# [CV 5/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=118, warm_start=True;, score=-0.960 total time=  52.7s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=2, n_estimators=336, warm_start=True;, score=-0.790 total time=  14.7s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=2, n_estimators=336, warm_start=True;, score=-0.785 total time=  20.3s
# [CV 2/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.820 total time=  42.4s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=2, n_estimators=336, warm_start=True;, score=-0.731 total time=  26.1s
# /Users/paddy/Library/Python/3.9/lib/python/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV 1/5] END bootstrap=True, max_features=1.0, min_samples_leaf=1, n_estimators=391, warm_start=False;, score=-0.778 total time=  21.5s
# [CV 3/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.775 total time= 1.1min
# [CV 1/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.768 total time=  18.5s
# [CV 2/5] END bootstrap=True, max_features=1.0, min_samples_leaf=1, n_estimators=391, warm_start=False;, score=-0.881 total time=  49.8s
# [CV 4/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.776 total time= 1.6min
# [CV 2/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.821 total time=  43.6s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=1, n_estimators=227, warm_start=True;, score=-0.785 total time=   3.3s
# [CV 3/5] END bootstrap=True, max_features=1.0, min_samples_leaf=1, n_estimators=391, warm_start=False;, score=-0.805 total time= 1.3min
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=1, n_estimators=227, warm_start=True;, score=-0.834 total time=   7.1s
# [CV 5/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.732 total time= 2.0min
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=1, n_estimators=227, warm_start=True;, score=-0.799 total time=  11.7s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=118, warm_start=True;, score=-0.796 total time=   1.2s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=118, warm_start=True;, score=-0.840 total time=   2.2s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=118, warm_start=True;, score=-0.810 total time=   3.3s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=1, n_estimators=227, warm_start=True;, score=-0.801 total time=  17.3s
# [CV 3/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.774 total time= 1.1min
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=118, warm_start=True;, score=-0.811 total time=   4.3s
# [CV 1/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=2, n_estimators=64, warm_start=True;, score=-0.784 total time=   0.6s
# [CV 2/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=2, n_estimators=64, warm_start=True;, score=-0.825 total time=   1.2s
# [CV 3/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=2, n_estimators=64, warm_start=True;, score=-0.792 total time=   2.0s
# [CV 4/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=2, n_estimators=64, warm_start=True;, score=-0.799 total time=   2.7s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=118, warm_start=True;, score=-0.752 total time=   5.3s
# [CV 5/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=2, n_estimators=64, warm_start=True;, score=-0.746 total time=   3.4s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=1, n_estimators=227, warm_start=True;, score=-0.742 total time=  21.8s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=391, warm_start=True;, score=-0.784 total time=   3.5s
# [CV 4/5] END bootstrap=True, max_features=1.0, min_samples_leaf=1, n_estimators=391, warm_start=False;, score=-0.798 total time= 1.8min
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=391, warm_start=True;, score=-0.819 total time=   7.5s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=391, warm_start=True;, score=-0.795 total time=  12.1s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=391, warm_start=True;, score=-0.791 total time=  16.3s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=391, warm_start=True;, score=-0.738 total time=  21.0s
# [CV 1/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=282, warm_start=True;, score=-1.083 total time=  24.6s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=500, warm_start=False;, score=-0.788 total time=   5.5s
# [CV 4/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.777 total time= 1.7min
# [CV 5/5] END bootstrap=True, max_features=1.0, min_samples_leaf=1, n_estimators=391, warm_start=False;, score=-0.760 total time= 2.4min
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=500, warm_start=False;, score=-0.825 total time=  11.4s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=500, warm_start=False;, score=-0.795 total time=  17.7s
# [CV 1/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=4, n_estimators=500, warm_start=False;, score=-0.776 total time=   4.2s
# [CV 2/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=282, warm_start=True;, score=-1.108 total time=  56.7s
# [CV 2/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=4, n_estimators=500, warm_start=False;, score=-0.815 total time=   8.2s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=500, warm_start=False;, score=-0.796 total time=  24.9s
# [CV 3/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=4, n_estimators=500, warm_start=False;, score=-0.790 total time=  13.3s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=173, warm_start=True;, score=-0.797 total time=   1.4s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=500, warm_start=False;, score=-0.739 total time=  31.6s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=173, warm_start=True;, score=-0.839 total time=   3.1s
# [CV 5/5] END bootstrap=True, max_features=1.0, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.731 total time= 2.2min
# [CV 4/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=4, n_estimators=500, warm_start=False;, score=-0.784 total time=  17.6s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=173, warm_start=True;, score=-0.814 total time=   4.7s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=173, warm_start=True;, score=-0.809 total time=   6.2s
# [CV 1/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=64, warm_start=False;, score=-1.083 total time=   5.3s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=173, warm_start=True;, score=-0.749 total time=   8.0s
# [CV 5/5] END bootstrap=True, max_features=sqrt, min_samples_leaf=4, n_estimators=500, warm_start=False;, score=-0.737 total time=  23.2s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=10, warm_start=True;, score=-0.854 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=10, warm_start=True;, score=-0.871 total time=   0.4s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=10, warm_start=True;, score=-0.856 total time=   0.4s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=10, warm_start=True;, score=-0.846 total time=   0.6s
# [CV 2/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=64, warm_start=False;, score=-1.107 total time=  12.3s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=1, n_estimators=10, warm_start=True;, score=-0.782 total time=   0.8s
# [CV 3/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=282, warm_start=True;, score=-1.038 total time= 1.5min
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=500, warm_start=False;, score=-0.794 total time=   4.4s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=500, warm_start=False;, score=-0.837 total time=   8.8s
# [CV 3/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=64, warm_start=False;, score=-1.040 total time=  20.2s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.784 total time=   4.0s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=500, warm_start=False;, score=-0.808 total time=  13.3s
# [CV 4/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=64, warm_start=False;, score=-1.043 total time=  27.9s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=500, warm_start=False;, score=-0.807 total time=  18.0s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.819 total time=   8.8s
# [CV 1/5] END bootstrap=True, max_features=log2, min_samples_leaf=2, n_estimators=10, warm_start=True;, score=-0.831 total time=   0.1s
# [CV 2/5] END bootstrap=True, max_features=log2, min_samples_leaf=2, n_estimators=10, warm_start=True;, score=-0.884 total time=   0.2s
# [CV 3/5] END bootstrap=True, max_features=log2, min_samples_leaf=2, n_estimators=10, warm_start=True;, score=-0.848 total time=   0.2s
# [CV 4/5] END bootstrap=True, max_features=log2, min_samples_leaf=2, n_estimators=10, warm_start=True;, score=-0.828 total time=   0.3s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_leaf=2, n_estimators=10, warm_start=True;, score=-0.778 total time=   0.4s
# [CV 5/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=64, warm_start=False;, score=-1.036 total time=  34.2s
# [CV 1/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-1.005 total time=   4.7s
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.795 total time=  13.2s
# [CV 5/5] END bootstrap=True, max_features=log2, min_samples_leaf=1, n_estimators=500, warm_start=False;, score=-0.749 total time=  22.9s
# [CV 2/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-1.082 total time=  11.0s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.788 total time=  18.2s
# [CV 1/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=118, warm_start=True;, score=-0.791 total time=   1.2s
# [CV 2/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=118, warm_start=True;, score=-0.825 total time=   2.8s
# [CV 4/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=282, warm_start=True;, score=-1.046 total time= 2.0min
# [CV 3/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=118, warm_start=True;, score=-0.794 total time=   4.2s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=4, n_estimators=445, warm_start=True;, score=-0.740 total time=  23.3s
# [CV 3/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-1.003 total time=  16.8s
# [CV 4/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=118, warm_start=True;, score=-0.801 total time=   5.5s
# [CV 5/5] END bootstrap=False, max_features=log2, min_samples_leaf=2, n_estimators=118, warm_start=True;, score=-0.745 total time=   7.3s
# [CV 4/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.989 total time=  23.3s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.777 total time=   5.6s
# [CV 1/5] END bootstrap=True, max_features=1.0, min_samples_leaf=2, n_estimators=336, warm_start=False;, score=-0.773 total time=  17.9s
# [CV 5/5] END bootstrap=False, max_features=1.0, min_samples_leaf=4, n_estimators=64, warm_start=True;, score=-0.960 total time=  30.7s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.812 total time=  11.5s
# [CV 5/5] END bootstrap=False, max_features=1.0, min_samples_leaf=2, n_estimators=282, warm_start=True;, score=-1.035 total time= 2.5min
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.784 total time=  17.1s
# [CV 2/5] END bootstrap=True, max_features=1.0, min_samples_leaf=2, n_estimators=336, warm_start=False;, score=-0.837 total time=  39.3s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.777 total time=  22.8s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_leaf=4, n_estimators=445, warm_start=False;, score=-0.731 total time=  26.1s
# [CV 3/5] END bootstrap=True, max_features=1.0, min_samples_leaf=2, n_estimators=336, warm_start=False;, score=-0.786 total time=  55.9s
# [CV 4/5] END bootstrap=True, max_features=1.0, min_samples_leaf=2, n_estimators=336, warm_start=False;, score=-0.788 total time= 1.2min
# [CV 5/5] END bootstrap=True, max_features=1.0, min_samples_leaf=2, n_estimators=336, warm_start=False;, score=-0.739 total time= 1.4min
# RandomizedSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#                    estimator=RandomForestRegressor(), n_iter=25, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_features': [1.0, 'sqrt', 'log2'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'n_estimators': [10, 64, 118, 173, 227,
#                                                          282, 336, 391, 445,
#                                                          500],
#                                         'warm_start': [True, False]},
#                    random_state=42,
#                    scoring=make_scorer(mean_absolute_scaled_error, greater_is_better=False),
#                    verbose=3)

# %%
print('Best Score: %s' % search.best_score_)
print('Best Hyperparameters: %s' % search.best_params_)
print('Best Model: %s' % search.best_estimator_)
print('Best Index: %s' % search.best_index_)
print('CV Results: %s' % search.cv_results_)
print('Refit Time: %s' % search.refit_time_)
print('Scorer: %s' % search.scorer_)
# Out:
# Best Score: -0.7741268514129792
# Best Hyperparameters: {'warm_start': False, 'n_estimators': 445, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': True}
# Best Model: RandomForestRegressor(min_samples_leaf=4, n_estimators=445)
# Best Index: 7
# CV Results: {'mean_fit_time': array([29.8294662 ,  9.88701644,  4.56859503,  2.18813014, 68.5188848 ,
#        14.72627268, 79.5327702 , 71.58935719, 12.0761723 ,  3.14633441,
#         1.922615  , 11.87879057, 88.53369713, 17.90922585, 13.10384469,
#         4.57200885, 19.93996162,  0.44331002, 13.14661474, 13.27816968,
#         0.23721099, 17.26934934,  4.12230663, 53.97136803, 16.42680979]), 'std_fit_time': array([15.77761591,  5.45420589,  2.34637581,  1.18547703, 36.56541406,
#         7.69185767, 42.44875864, 39.45785861,  6.63842398,  1.44402449,
#         0.97243061,  6.16541432, 44.95755672,  9.2637836 ,  6.70816963,
#         2.2920867 , 10.35230793,  0.19493176,  6.47645111,  6.73509254,
#         0.11886139,  9.09574222,  2.08539091, 23.82831978,  7.42651514]), 'mean_score_time': array([0.05100055, 0.03383183, 0.06414871, 0.04711022, 0.1857511 ,
#        0.20067701, 0.24631953, 0.19984183, 0.17517605, 0.10050206,
#        0.04775305, 0.20098891, 0.17347069, 0.30390348, 0.21488657,
#        0.12073565, 0.03811555, 0.01513343, 0.33660722, 0.22276039,
#        0.01043324, 0.02658081, 0.07825761, 0.13006434, 0.19247189]), 'std_score_time': array([0.01608248, 0.01033911, 0.00917082, 0.01114946, 0.03105698,
#        0.03757395, 0.05402707, 0.03579353, 0.05256233, 0.04206521,
#        0.01967627, 0.03773644, 0.028797  , 0.05171675, 0.01355646,
#        0.01241277, 0.00708078, 0.00383405, 0.05572575, 0.03965281,
#        0.00179384, 0.00511462, 0.00604831, 0.00649913, 0.01636084]), 'param_warm_start': masked_array(data=[True, True, False, True, True, True, False, False,
#                    True, True, True, True, True, False, False, True,
#                    False, True, False, True, True, True, True, False,
#                    False],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[118, 64, 118, 64, 445, 336, 391, 445, 227, 118, 64,
#                    391, 282, 500, 500, 173, 64, 10, 500, 445, 10, 64, 118,
#                    336, 445],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_min_samples_leaf': masked_array(data=[4, 4, 4, 1, 4, 2, 1, 4, 1, 1, 2, 4, 2, 2, 4, 1, 2, 1,
#                    1, 4, 2, 4, 2, 2, 4],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_max_features': masked_array(data=[1.0, 1.0, 'sqrt', 'log2', 1.0, 'sqrt', 1.0, 1.0,
#                    'sqrt', 'log2', 'sqrt', 'log2', 1.0, 'log2', 'sqrt',
#                    'log2', 1.0, 'log2', 'log2', 'log2', 'log2', 1.0,
#                    'log2', 1.0, 'sqrt'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'param_bootstrap': masked_array(data=[False, True, False, False, True, False, True, True,
#                    False, True, True, False, False, False, True, True,
#                    False, False, True, False, True, False, False, True,
#                    False],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False],
#        fill_value='?',
#             dtype=object), 'params': [{'warm_start': True, 'n_estimators': 118, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': False}, {'warm_start': True, 'n_estimators': 64, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': True}, {'warm_start': False, 'n_estimators': 118, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False}, {'warm_start': True, 'n_estimators': 64, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': True, 'n_estimators': 445, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': True}, {'warm_start': True, 'n_estimators': 336, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False}, {'warm_start': False, 'n_estimators': 391, 'min_samples_leaf': 1, 'max_features': 1.0, 'bootstrap': True}, {'warm_start': False, 'n_estimators': 445, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': True}, {'warm_start': True, 'n_estimators': 227, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}, {'warm_start': True, 'n_estimators': 118, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}, {'warm_start': True, 'n_estimators': 64, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True}, {'warm_start': True, 'n_estimators': 391, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': True, 'n_estimators': 282, 'min_samples_leaf': 2, 'max_features': 1.0, 'bootstrap': False}, {'warm_start': False, 'n_estimators': 500, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': False, 'n_estimators': 500, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': True}, {'warm_start': True, 'n_estimators': 173, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}, {'warm_start': False, 'n_estimators': 64, 'min_samples_leaf': 2, 'max_features': 1.0, 'bootstrap': False}, {'warm_start': True, 'n_estimators': 10, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': False, 'n_estimators': 500, 'min_samples_leaf': 1, 'max_features': 'log2', 'bootstrap': True}, {'warm_start': True, 'n_estimators': 445, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': True, 'n_estimators': 10, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': True}, {'warm_start': True, 'n_estimators': 64, 'min_samples_leaf': 4, 'max_features': 1.0, 'bootstrap': False}, {'warm_start': True, 'n_estimators': 118, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': False}, {'warm_start': False, 'n_estimators': 336, 'min_samples_leaf': 2, 'max_features': 1.0, 'bootstrap': True}, {'warm_start': False, 'n_estimators': 445, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False}], 'split0_test_score': array([-1.00428058, -0.77564056, -0.77551602, -0.80311707, -0.77205313,
#        -0.78335055, -0.77818074, -0.76757886, -0.78508515, -0.79625219,
#        -0.78381665, -0.78411098, -1.08302119, -0.78808316, -0.77606864,
#        -0.79748178, -1.08276121, -0.85443031, -0.79427222, -0.7843876 ,
#        -0.8311345 , -1.00510511, -0.7910257 , -0.77286288, -0.77733101]), 'split1_test_score': array([-1.08198844, -0.82069542, -0.81272641, -0.84455426, -0.82001365,
#        -0.81907182, -0.88137707, -0.82102547, -0.83433798, -0.84014935,
#        -0.8247829 , -0.81922934, -1.10756558, -0.82498009, -0.81476379,
#        -0.83919086, -1.10663094, -0.87115224, -0.8366097 , -0.81934809,
#        -0.8843259 , -1.08247692, -0.82453459, -0.83654588, -0.81161718]), 'split2_test_score': array([-1.00380568, -0.78303348, -0.78562327, -0.81185352, -0.77478377,
#        -0.78998092, -0.80496983, -0.77403418, -0.79862505, -0.81002807,
#        -0.79233643, -0.79546419, -1.03805083, -0.79462645, -0.79006102,
#        -0.81371513, -1.03950539, -0.85610344, -0.80781004, -0.7948135 ,
#        -0.84808865, -1.00347361, -0.79411767, -0.78567544, -0.78429602]), 'split3_test_score': array([-0.98832446, -0.77896823, -0.78086028, -0.80711425, -0.77562087,
#        -0.78521877, -0.79770539, -0.7766251 , -0.80115817, -0.81118545,
#        -0.79928172, -0.79089491, -1.04577695, -0.79587668, -0.78363957,
#        -0.80897662, -1.04342965, -0.84593415, -0.80686204, -0.78806497,
#        -0.82790575, -0.9892869 , -0.80092592, -0.78795344, -0.77696652]), 'split4_test_score': array([-0.96041961, -0.7339845 , -0.73512344, -0.75102987, -0.73217343,
#        -0.73080906, -0.75984878, -0.73137064, -0.74160247, -0.75216658,
#        -0.74556163, -0.73794482, -1.03547178, -0.73909627, -0.73673102,
#        -0.74868252, -1.03571642, -0.78222701, -0.74894769, -0.73984596,
#        -0.77759018, -0.96022468, -0.74455206, -0.73941345, -0.73075508]), 'mean_test_score': array([-1.00776375, -0.77846444, -0.77796988, -0.80353379, -0.77492897,
#        -0.78168622, -0.80441636, -0.77412685, -0.79216177, -0.80195633,
#        -0.78915587, -0.78552885, -1.06197727, -0.78853253, -0.78025281,
#        -0.80160938, -1.06160872, -0.84196943, -0.79890034, -0.78529202,
#        -0.833809  , -1.00811344, -0.79103119, -0.78449022, -0.77619316]), 'std_test_score': array([0.04038925, 0.02753552, 0.02496711, 0.03007175, 0.02781883,
#        0.02853145, 0.04157613, 0.02855416, 0.0300262 , 0.02870746,
#        0.02573285, 0.0265687 , 0.02849072, 0.027798  , 0.02533903,
#        0.02977073, 0.02815626, 0.0309566 , 0.0285708 , 0.02578498,
#        0.03452078, 0.04051735, 0.02603928, 0.03127395, 0.02602702]), 'rank_test_score': array([22,  5,  4, 18,  2,  7, 19,  1, 14, 17, 12, 10, 25, 11,  6, 16, 24,
#        21, 15,  9, 20, 23, 13,  8,  3], dtype=int32)}
# Refit Time: 96.60666608810425
# Scorer: make_scorer(mean_absolute_scaled_error, greater_is_better=False)
